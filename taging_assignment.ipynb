# %%
with open('brown.txt','r') as f:
	corpus = f.read() 
	#print(corpus)

# %%
words = corpus.split()        # split function converting whole corpus in to list of words so it will be eassy to handle
#print(words[:])

# %%
N = len(words)
print(N)
# Out:
# 1161192

# %%
brown_test = []
brown_train = []
sen = 0
for i in words:
    if i == './.':
        sen += 1
    if sen < 2000:
        brown_test.append(i)
    else:
        brown_train.append(i)

# %%
print(len(brown_test))
print(len(brown_train))
# Out:
# 49948
# 1111244

# %%
# getting frequency of tags from brown_train
import collections
types =  collections.Counter(brown_train)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
a = []
for value in types.items() :
    a.append(value)
#print(a)

#sorting array "a" in decending order
def sortthird(a): 
    return a[1] 
a.sort(key = sortthird ,reverse = True) 
#print(a)

#spliting words and tags fron sorted array "a"
b = []
t = 0 
for i in a:
    x = a[t][0]
    j = x.rsplit('/')
    b.append(j)
    t += 1 
# len of b is 64413
    
#cosidering only maximum frequent word-tag pairs from array "b" 
temp =[]
max_fre_word_tag = []
for l in b:
    if (l[0] not in temp):
        temp.append(l[0])
        max_fre_word_tag.append(l)
    
print(max_fre_word_tag)  # now the size of training set come down to 54068 from 1111244 word_tags pairs
# Out:
# [['the', 'at'], [',', ','], ['.', '.'], ['of', 'in'], ['and', 'cc'], ['a', 'at'], ['in', 'in'], ['to', 'to'], ['is', 'bez'], ['was', 'bedz'], ['``', '``'], ["''", "''"], ['for', 'in'], ['with', 'in'], ['he', 'pps'], ['The', 'at'], ['his', 'pp$'], ['that', 'cs'], ['be', 'be'], [';', '.'], ['on', 'in'], ['as', 'cs'], ['I', 'ppss'], ['by', 'in'], ['had', 'hvd'], ['at', 'in'], ['?', '.'], ['not', '*'], ['are', 'ber'], ['from', 'in'], ['or', 'cc'], ['this', 'dt'], ['have', 'hv'], ['it', 'pps'], ['which', 'wdt'], ['an', 'at'], ['--', '--'], ['were', 'bed'], ['He', 'pps'], ['but', 'cc'], ['they', 'ppss'], ['him', 'ppo'], ['would', 'md'], ['all', 'abn'], ['their', 'pp$'], ['been', 'ben'], ['one', 'cd'], ['has', 'hvz'], [')', ')'], ['(', '('], ['who', 'wps'], ['It', 'pps'], ['she', 'pps'], ['we', 'ppss'], ['will', 'md'], ['you', 'ppss'], ['them', 'ppo'], ['her', 'pp$'], ['into', 'in'], ['In', 'in'], ['its', 'pp$'], ['can', 'md'], ['when', 'wrb'], ['up', 'rp'], ['!', '.'], ['other', 'ap'], ['out', 'rp'], ['could', 'md'], ['no', 'at'], ['time', 'nn'], [':', ':'], ['said', 'vbd'], ['if', 'cs'], ['what', 'wdt'], ['some', 'dti'], ['But', 'cc'], ['there', 'ex'], ['may', 'md'], ['than', 'cs'], ['any', 'dti'], ['only', 'rb'], ['do', 'do'], ['two', 'cd'], ['these', 'dts'], ['about', 'in'], ['me', 'ppo'], ['my', 'pp$'], ['This', 'dt'], ['our', 'pp$'], ['man', 'nn'], ['A', 'at'], ['now', 'rb'], ['Af', 'nn'], ['then', 'rb'], ['more', 'ql'], ['new', 'jj'], ['must', 'md'], ['did', 'dod'], ['like', 'cs'], ['also', 'rb'], ['She', 'pps'], ['years', 'nns'], ['so', 'ql'], ['such', 'jj'], ['many', 'ap'], ['first', 'od'], ['way', 'nn'], ['your', 'pp$'], ['through', 'in'], ['And', 'cc'], ['They', 'ppss'], ['should', 'md'], ['where', 'wrb'], ['even', 'rb'], ['There', 'ex'], ['people', 'nns'], ['over', 'in'], ['those', 'dts'], ['make', 'vb'], ['own', 'jj'], ['each', 'dt'], ['Mr.', 'np'], ['If', 'cs'], ['men', 'nns'], ['see', 'vb'], ['between', 'in'], ['back', 'rb'], ['get', 'vb'], ['good', 'jj'], ['down', 'rp'], ['life', 'nn'], ['same', 'ap'], ['very', 'ql'], ['still', 'rb'], ['world', 'nn'], ['us', 'ppo'], ['We', 'ppss'], ['just', 'rb'], ['know', 'vb'], ['because', 'cs'], ['never', 'rb'], ['might', 'md'], ['being', 'beg'], ['well', 'rb'], ['made', 'vbn'], ['most', 'ql'], ['both', 'abx'], ['came', 'vbd'], ['under', 'in'], ['day', 'nn'], ['himself', 'ppl'], ['great', 'jj'], ['go', 'vb'], ['few', 'ap'], ['year', 'nn'], ['against', 'in'], ['When', 'wrb'], ['old', 'jj'], ['here', 'rb'], ['work', 'nn'], ['another', 'dt'], ['take', 'vb'], ['again', 'rb'], ['without', 'in'], ['His', 'pp$'], ['You', 'ppss'], ['too', 'ql'], ['long', 'jj'], ['small', 'jj'], ['New', 'jj-tl'], ['three', 'cd'], ['after', 'in'], ['went', 'vbd'], ['last', 'ap'], ['how', 'wrb'], ['For', 'in'], ['used', 'vbn'], ['place', 'nn'], ['say', 'vb'], ['state', 'nn'], ['while', 'cs'], ['As', 'cs'], ['course', 'nn'], ['off', 'rp'], ['much', 'ap'], ['part', 'nn'], ['away', 'rb'], ['number', 'nn'], ['always', 'rb'], ['What', 'wdt'], ['fact', 'nn'], ['every', 'at'], ['upon', 'in'], ['does', 'doz'], ['during', 'in'], ['United', 'vbn-tl'], ['think', 'vb'], ['something', 'pn'], ['water', 'nn'], ['took', 'vbd'], ['States', 'nns-tl'], ['American', 'jj'], ['hand', 'nn'], ['high', 'jj'], ['head', 'nn'], ['At', 'in'], ['eyes', 'nns'], ['knew', 'vbd'], ["didn't", 'dod*'], ['little', 'ap'], ['find', 'vb'], ['before', 'cs'], ['system', 'nn'], ["don't", 'do*'], ['come', 'vb'], ['going', 'vbg'], ['school', 'nn'], ['house', 'nn'], ['toward', 'in'], ['group', 'nn'], ['important', 'jj'], ['possible', 'jj'], ['room', 'nn'], ['give', 'vb'], ['once', 'rb'], ['nothing', 'pn'], ['things', 'nns'], ['side', 'nn'], ['days', 'nns'], ['given', 'vbn'], ['end', 'nn'], ['night', 'nn'], ['often', 'rb'], ['social', 'jj'], ['use', 'nn'], ['business', 'nn'], ['point', 'nn'], ['young', 'jj'], ['though', 'cs'], ['These', 'dts'], ['large', 'jj'], ['per', 'in'], ['case', 'nn'], ['order', 'nn'], ['thought', 'vbd'], ['saw', 'vbd'], ['Then', 'r ...

# %%
# word_tags pair from brown_test corpus
# getting frequency of tags from brown_test
import collections
types =  collections.Counter(brown_test)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
s = []
for value in types.items() :
    s.append(value)
#print(a)

#sorting array "a" in decending order
def sortthird(s): 
    return s[1] 
s.sort(key = sortthird ,reverse = True) 
#print(a)

#spliting words and tags fron sorted array "a"
test_words = []
t = 0 
for i in s:
    x = s[t][0]
    j = x.rsplit('/')
    test_words.append(j)
    t += 1 
# len of test_words1 is 10061    
print(test_words)  # now the size of test set come down to 10061 from 49948 word_tags pairs
# Out:
# [['the', 'at'], [',', ','], ['.', '.'], ['of', 'in'], ['and', 'cc'], ['a', 'at'], ['in', 'in'], ['to', 'to'], ['for', 'in'], ['to', 'in'], ['The', 'at'], ['``', '``'], ["''", "''"], ['was', 'bedz'], ['is', 'bez'], ['on', 'in'], ['be', 'be'], ['at', 'in'], ['said', 'vbd'], ['that', 'cs'], ['by', 'in'], ['will', 'md'], ['he', 'pps'], ['with', 'in'], ['his', 'pp$'], ['Mrs.', 'np'], ['as', 'cs'], ['would', 'md'], ['has', 'hvz'], ['who', 'wps'], ['an', 'at'], ['from', 'in'], ['are', 'ber'], ['--', '--'], ['have', 'hv'], ['were', 'bed'], ['He', 'pps'], ['been', 'ben'], ['not', '*'], ['this', 'dt'], ['Mr.', 'np'], ['which', 'wdt'], ['had', 'hvd'], ['their', 'pp$'], ['it', 'pps'], ['two', 'cd'], ['one', 'cd'], ['last', 'ap'], ['they', 'ppss'], ['I', 'ppss'], ['but', 'cc'], ['its', 'pp$'], ['or', 'cc'], ['year', 'nn'], ['of', 'in-tl'], [';', '.'], ['first', 'od'], ['when', 'wrb'], ['out', 'rp'], ['also', 'rb'], ['other', 'ap'], ['new', 'jj'], ['A', 'at'], ['It', 'pps'], ['it', 'ppo'], ['up', 'rp'], ['more', 'ap'], ['all', 'abn'], ['state', 'nn'], ['years', 'nns'], ['into', 'in'], ['In', 'in'], ['three', 'cd'], ['over', 'in'], ['no', 'at'], [':', ':'], ['there', 'ex'], ['that', 'wps'], ['night', 'nn'], ['some', 'dti'], ['her', 'pp$'], ['that', 'dt'], [',', ',-hl'], ['against', 'in'], ['(', '('], ['administration', 'nn'], [')', ')'], ['him', 'ppo'], ['New', 'jj-tl'], ['game', 'nn'], ['city', 'nn'], ['now', 'rb'], ['But', 'cc'], ['after', 'in'], ['Monday', 'nr'], ['State', 'nn-tl'], ['can', 'md'], ['should', 'md'], ['after', 'cs'], ['them', 'ppo'], ['United', 'vbn-tl'], ['could', 'md'], ['home', 'nn'], ['time', 'nn'], ['here', 'rb'], ['what', 'wdt'], ['program', 'nn'], ['Jr.', 'np'], ['if', 'cs'], ['under', 'in'], ['we', 'ppss'], ['bill', 'nn'], ['Miss', 'np'], ['did', 'dod'], ['today', 'nr'], ['John', 'np'], ['home', 'nr'], ['man', 'nn'], ['during', 'in'], ['four', 'cd'], ['President', 'nn-tl'], ['House', 'nn-tl'], ['school', 'nn'], ['back', 'rb'], ['Sunday', 'nr'], ['election', 'nn'], ['week', 'nn'], ['per', 'in'], ['members', 'nns'], ['yesterday', 'nr'], ['This', 'dt'], ['made', 'vbn'], ['government', 'nn'], ['States', 'nns-tl'], ['where', 'wrb'], ['day', 'nn'], ["'", "'"], ['plan', 'nn'], ['than', 'in'], ['get', 'vb'], ['tax', 'nn'], ['committee', 'nn'], ['only', 'ap'], ['as', 'ql'], ['Democratic', 'jj-tl'], ['season', 'nn'], ['about', 'in'], ['A.', 'np'], ['James', 'np'], ['City', 'nn-tl'], ['J.', 'np'], ['jury', 'nn'], ['any', 'dti'], ['people', 'nns'], ['board', 'nn'], ['million', 'cd'], ['being', 'beg'], ['Friday', 'nr'], ['1', 'cd'], ['before', 'in'], ['take', 'vb'], ['Tuesday', 'nr'], ['party', 'nn'], ['ball', 'nn'], ['than', 'cs'], ['?', '.'], ['University', 'nn-tl'], ['team', 'nn'], ['made', 'vbd'], ['president', 'nn'], ['chairman', 'nn'], ['both', 'abx'], ['each', 'dt'], ['meeting', 'nn'], ['several', 'ap'], ['make', 'vb'], ['cent', 'nn'], ['days', 'nns'], ['C.', 'np'], ['do', 'do'], ['Dr.', 'nn-tl'], ['expected', 'vbn'], ['federal', 'jj'], ['told', 'vbd'], ['They', 'ppss'], ['Saturday', 'nr'], ['another', 'dt'], ['must', 'md'], ['schools', 'nns'], ['County', 'nn-tl'], ['such', 'jj'], ['children', 'nns'], ['about', 'rb'], ['W.', 'np'], ['off', 'rp'], ['in', 'rp'], ['only', 'rb'], ['There', 'ex'], ['then', 'rb'], ['session', 'nn'], ['third', 'od'], ['next', 'ap'], ['club', 'nn'], ['special', 'jj'], ['go', 'vb'], ['between', 'in'], ['five', 'cd'], ['without', 'in'], ['down', 'rp'], ['B.', 'np'], ['former', 'ap'], ['York', 'np-tl'], ['10', 'cd'], ['His', 'pp$'], ['our', 'pp$'], ['E.', 'np'], ['given', 'vbn'], ['William', 'np'], ['most', 'ql'], ['Hughes', 'np'], ['those', 'dts'], ['Laos', 'np'], ['law', 'nn'], ['may', 'md'], ['work', 'nn'], ['men', 'nns'], ['L.', 'np'], ['through', 'in'], ['local', 'jj'], ['these', 'dts'], ['D.', 'np'], ['came', 'vbd'], ['give', 'vb'], ['play', 'vb'], ['National', 'jj-tl'], ['Texas', 'np'], ['record', 'nn'], ['Committee', 'nn-tl'], ['director', 'nn'], ['just', 'rb'], ['daughter', 'nn'], ['taken', ...

# %%
#maximum occuring tag in training corpus
mt = []
for i in max_fre_word_tag:
    mt.append(i[1])

import collections
mmt =  collections.Counter(mt)
#print(mmt)  # list of maxximum occuring tag

# %%
#unigram tagger for each unique words from training corpus

unigram_tag = []
y = len(max_fre_word_tag)
for i in test_words:
    for l in range(y): 
        if (i[0] == max_fre_word_tag[l][0]):
            temp = [i , max_fre_word_tag[l][1]]
            unigram_tag.append(temp)
            break;
#unigram_tag
temp = []
for i in unigram_tag:
    temp.append(i[0])

for i in test_words:
    if(i not in temp):
        temp1 = [i , 'unk']
        unigram_tag.append(temp1)
        
print(unigram_tag) # unknown words are tagged as 'unk' tag at the bottom of list 

# we can tag unknown words by taking maximum occurring tag in this case it is "nn" have frequency 12403
# Out:
# [[['the', 'at'], 'at'], [[',', ','], ','], [['.', '.'], '.'], [['of', 'in'], 'in'], [['and', 'cc'], 'cc'], [['a', 'at'], 'at'], [['in', 'in'], 'in'], [['to', 'to'], 'to'], [['for', 'in'], 'in'], [['to', 'in'], 'to'], [['The', 'at'], 'at'], [['``', '``'], '``'], [["''", "''"], "''"], [['was', 'bedz'], 'bedz'], [['is', 'bez'], 'bez'], [['on', 'in'], 'in'], [['be', 'be'], 'be'], [['at', 'in'], 'in'], [['said', 'vbd'], 'vbd'], [['that', 'cs'], 'cs'], [['by', 'in'], 'in'], [['will', 'md'], 'md'], [['he', 'pps'], 'pps'], [['with', 'in'], 'in'], [['his', 'pp$'], 'pp$'], [['Mrs.', 'np'], 'np'], [['as', 'cs'], 'cs'], [['would', 'md'], 'md'], [['has', 'hvz'], 'hvz'], [['who', 'wps'], 'wps'], [['an', 'at'], 'at'], [['from', 'in'], 'in'], [['are', 'ber'], 'ber'], [['--', '--'], '--'], [['have', 'hv'], 'hv'], [['were', 'bed'], 'bed'], [['He', 'pps'], 'pps'], [['been', 'ben'], 'ben'], [['not', '*'], '*'], [['this', 'dt'], 'dt'], [['Mr.', 'np'], 'np'], [['which', 'wdt'], 'wdt'], [['had', 'hvd'], 'hvd'], [['their', 'pp$'], 'pp$'], [['it', 'pps'], 'pps'], [['two', 'cd'], 'cd'], [['one', 'cd'], 'cd'], [['last', 'ap'], 'ap'], [['they', 'ppss'], 'ppss'], [['I', 'ppss'], 'ppss'], [['but', 'cc'], 'cc'], [['its', 'pp$'], 'pp$'], [['or', 'cc'], 'cc'], [['year', 'nn'], 'nn'], [['of', 'in-tl'], 'in'], [[';', '.'], '.'], [['first', 'od'], 'od'], [['when', 'wrb'], 'wrb'], [['out', 'rp'], 'rp'], [['also', 'rb'], 'rb'], [['other', 'ap'], 'ap'], [['new', 'jj'], 'jj'], [['A', 'at'], 'at'], [['It', 'pps'], 'pps'], [['it', 'ppo'], 'pps'], [['up', 'rp'], 'rp'], [['more', 'ap'], 'ql'], [['all', 'abn'], 'abn'], [['state', 'nn'], 'nn'], [['years', 'nns'], 'nns'], [['into', 'in'], 'in'], [['In', 'in'], 'in'], [['three', 'cd'], 'cd'], [['over', 'in'], 'in'], [['no', 'at'], 'at'], [[':', ':'], ':'], [['there', 'ex'], 'ex'], [['that', 'wps'], 'cs'], [['night', 'nn'], 'nn'], [['some', 'dti'], 'dti'], [['her', 'pp$'], 'pp$'], [['that', 'dt'], 'cs'], [[',', ',-hl'], ','], [['against', 'in'], 'in'], [['(', '('], '('], [['administration', 'nn'], 'nn'], [[')', ')'], ')'], [['him', 'ppo'], 'ppo'], [['New', 'jj-tl'], 'jj-tl'], [['game', 'nn'], 'nn'], [['city', 'nn'], 'nn'], [['now', 'rb'], 'rb'], [['But', 'cc'], 'cc'], [['after', 'in'], 'in'], [['Monday', 'nr'], 'nr'], [['State', 'nn-tl'], 'nn-tl'], [['can', 'md'], 'md'], [['should', 'md'], 'md'], [['after', 'cs'], 'in'], [['them', 'ppo'], 'ppo'], [['United', 'vbn-tl'], 'vbn-tl'], [['could', 'md'], 'md'], [['home', 'nn'], 'nr'], [['time', 'nn'], 'nn'], [['here', 'rb'], 'rb'], [['what', 'wdt'], 'wdt'], [['program', 'nn'], 'nn'], [['Jr.', 'np'], 'np'], [['if', 'cs'], 'cs'], [['under', 'in'], 'in'], [['we', 'ppss'], 'ppss'], [['bill', 'nn'], 'nn'], [['Miss', 'np'], 'np'], [['did', 'dod'], 'dod'], [['today', 'nr'], 'nr'], [['John', 'np'], 'np'], [['home', 'nr'], 'nr'], [['man', 'nn'], 'nn'], [['during', 'in'], 'in'], [['four', 'cd'], 'cd'], [['President', 'nn-tl'], 'nn-tl'], [['House', 'nn-tl'], 'nn-tl'], [['school', 'nn'], 'nn'], [['back', 'rb'], 'rb'], [['Sunday', 'nr'], 'nr'], [['election', 'nn'], 'nn'], [['week', 'nn'], 'nn'], [['per', 'in'], 'in'], [['members', 'nns'], 'nns'], [['yesterday', 'nr'], 'nr'], [['This', 'dt'], 'dt'], [['made', 'vbn'], 'vbn'], [['government', 'nn'], 'nn'], [['States', 'nns-tl'], 'nns-tl'], [['where', 'wrb'], 'wrb'], [['day', 'nn'], 'nn'], [["'", "'"], "'"], [['plan', 'nn'], 'nn'], [['than', 'in'], 'cs'], [['get', 'vb'], 'vb'], [['tax', 'nn'], 'nn'], [['committee', 'nn'], 'nn'], [['only', 'ap'], 'rb'], [['as', 'ql'], 'cs'], [['Democratic', 'jj-tl'], 'jj-tl'], [['season', 'nn'], 'nn'], [['about', 'in'], 'in'], [['A.', 'np'], 'np'], [['James', 'np'], 'np'], [['City', 'nn-tl'], 'nn-tl'], [['J.', 'np'], 'np'], [['jury', 'nn'], 'nn'], [['any', 'dti'], 'dti'], [['people', 'nns'], 'nns'], [['board', 'nn'], 'nn'], [['million', 'cd'], 'cd'], [['being', 'beg'], 'beg'], [['Friday', 'nr'], 'nr'], [['1', 'cd'], 'cd'], [['before', 'in'], 'cs'], [['take', 'vb'], 'vb'], [['Tuesday', 'nr'], 'nr'], [['party', 'nn'], ...

# %%
len(unigram_tag)
# Out:
# 10061

# %%
# bigram tagging model of brown_train corpus
# seprating tags and words and counting each word tag pair for brown _train
q = []
for i in brown_train:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_train = [[]for i in range(x)]
for i in range(x):
    if i+1 < x:   
        bigram_train[i].append( q[i] )   
        bigram_train[i].append( q[i+1])
    
#print (bigram_train)   #bigram_train list have 1111244 

x = len(bigram_train)
bigram_tag = []
for i in range(x-1):
    p =[bigram_train[i][0][1] , bigram_train[i][1][1]]
    bigram_tag.append(p)
    
    
# getting frequency of tags from brown_train
from collections import Counter
types =  Counter(tuple(x) for x in bigram_tag)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
s = []
for value in types.items() :
    s.append(value)
#print(s)

#sorting array "a" in decending order
def sortthird(s): 
    return s[1] 
s.sort(key = sortthird ,reverse = True) 
#print(s)            # bigram_training corpus get reduced from 1111244 to 455628 pairs

q = [] 
for i in s:
    q.append(i[0])

temp =[]
bi_max_fre_word_tag = []
for l in q:
    if (l[0] not in temp):
        temp.append(l[0])
        bi_max_fre_word_tag.append(l)
    
print(bi_max_fre_word_tag)  # now the size of training set come down to 519 from 1111244 word_tags pairs
# Out:
# [('at', 'nn'), ('in', 'at'), ('nn', 'in'), ('jj', 'nn'), ('nns', 'in'), ('to', 'vb'), ('vbn', 'in'), (',', 'cc'), ('pp$', 'nn'), ('.', 'at'), ('np', 'np'), ('pps', 'vbd'), ('vb', 'at'), ('cs', 'at'), ('rb', 'in'), ('md', 'vb'), ("''", '.'), ('ql', 'jj'), ('dt', 'nn'), ('vbd', 'in'), ('cc', 'nn'), ('cd', 'nns'), ('ppss', 'vb'), ('be', 'vbn'), ('vbg', 'in'), ('ap', 'nn'), ('hvd', 'vbn'), ('bedz', 'vbn'), ('ppo', '.'), ('rp', 'in'), ('bez', 'at'), ('nn-tl', 'nn-tl'), ('jj-tl', 'nn-tl'), ('vbz', 'at'), ('np-tl', 'nn-tl'), ('hv', 'vbn'), ('np$', 'nn'), ('dts', 'nns'), ('dti', 'nn'), ('*', 'vb'), ('ben', 'vbn'), ('od', 'nn'), ('ber', 'vbn'), ('bed', 'vbn'), ('``', 'ppss'), ('wps', 'vbd'), ('hvz', 'vbn'), ('nn$', 'nn'), ('wrb', 'pps'), ('jjr', 'nn'), ('ex', 'bedz'), ('wdt', 'ppss'), ('md*', 'vb'), (':', '``'), ('abn', 'at'), ('pn', 'in'), ('vbn-tl', 'nns-tl'), ('dod', '*'), ('--', 'cc'), (')', '.'), ('(', 'np'), ('in-tl', 'np-tl'), ('jjt', 'nn'), ('do*', 'vb'), ('nns-tl', ','), ('at-tl', 'nn-tl'), ('uh', ','), ('beg', 'vbn'), ('abl', 'at'), ('dod*', 'vb'), ('ppss+md', 'vb'), ('cd-tl', ','), ('nr', 'in'), ('nn-hl', 'in-hl'), ('cd-hl', '.-hl'), ('ppl', '.'), ('doz', '*'), ('nps', ','), ('do', '*'), ('jj-hl', 'nn-hl'), ('jjs', 'nn'), ('abx', 'nns'), ('at-hl', 'nn-hl'), ('rbr', ','), ('in-hl', 'at-hl'), ('ppss+hv', 'vbn'), ('od-tl', 'nn-tl'), ('nn$-tl', 'nn'), ('nil', 'nil'), ('wp$', 'nn'), ('nns$', 'nn'), ('nns-hl', 'in-hl'), ('qlp', 'to'), ('cc-tl', 'nn-tl'), ('.-hl', 'at'), ('pps+bez', 'at'), ('hvg', 'vbn'), ('ppls', 'in'), ('ppss+ber', 'vbg'), ('hvn', 'at'), ('np$-tl', 'nn-tl'), ('np-hl', ')-hl'), ('(-hl', 'np-hl'), ('pps+md', 'vb'), ('doz*', 'vb'), ('wpo', 'pps'), ('ppss+bem', 'jj'), ('wql', 'jj'), ('hvd*', 'vbn'), ('nr-tl', '.'), ('vb+ppo', 'vb'), ('vbg-tl', 'nn-tl'), ('pp$$', '.'), ('pps+hvd', 'vbn'), ('cc-hl', 'nn-hl'), ('pn$', 'nn'), ('ex+bez', 'at'), ('fw-in', 'fw-nn'), ('to-hl', 'vb-hl'), ('fw-nn', ','), ('dtx', 'nn'), ('ppss+hvd', 'vbn'), (',-hl', 'np-hl'), ('vbg-hl', 'nns-hl'), ('bem', 'jj'), ("'", "''"), ('nns$-tl', 'nn-tl'), (')-hl', 'at'), ('dt+bez', 'at'), ('nn-nc', "''"), ('at-nc', 'nn-nc'), ('rbt', 'vbn'), ('fw-nn-tl', 'fw-jj-tl'), ('pps+hvz', 'vbn'), ('hv*', 'vbn'), (':-tl', 'cd-tl'), ('bez*', 'pps'), ('nn-tl-hl', 'nn-tl-hl'), ('vbn-hl', 'in-hl'), ('vb-tl', "''"), ('fw-at-tl', 'fw-nn-tl'), ('pp$-tl', 'nn-tl'), ('bedz*', 'at'), ('fw-nns', ','), ('vb-hl', ':-hl'), ('wrb-hl', 'to-hl'), ('nr$', 'nn'), ('nn$-hl', 'nn-hl'), ('2', 'nns'), ('fw-jj', 'fw-nn'), (':-hl', 'nn'), ('fw-jj-tl', 'fw-nn-tl'), ('jjs-tl', 'nn-tl'), ('ap-hl', 'nn-hl'), ('pps-hl', 'doz-hl'), ('', 'nn'), ('fw-at', 'fw-nn'), ('doz-hl', ':-hl'), ('wdt-hl', 'pps-hl'), ("4''", "''"), ('ber*', 'ppss'), ('wdt+bez', 'at'), ('jj-tl-hl', 'nn-tl-hl'), ('hvz*', 'vbn'), ('ap-tl', 'nn-tl'), ('fw-cc', 'fw-nns'), ('ppss-hl', 'vb-hl'), ('cd-tl-hl', '.-hl'), ('fw-in-tl', 'fw-nn-tl'), ('4', 'nn'), ('to-tl', 'vb-tl'), ('nps-tl', '.'), ('be-hl', 'vbn-hl'), ('cs-hl', 'ppss-hl'), ("2''", "''"), ('bez-hl', 'jj-hl'), ('vbg+to', 'vb'), ('md-hl', 'vb-hl'), ('to-nc', 'vb-nc'), ('nps$', 'nn'), ('.-nc', '.-nc'), ('rb-tl', 'in-tl'), ('fw-in+at-tl', 'fw-nn-tl'), ('jj-nc', "''"), ('ber-hl', 'vbn-hl'), ('fw-rb', 'fw-vbn'), ('ppss-nc', 'vbd-nc'), ("8''", "''"), ('jjr-tl', 'nn-tl'), ('vbz-hl', 'nn-hl'), ('rb-hl', 'cd-hl'), ('rb+bez', 'at'), ('nn+bez', 'vbn'), ('wrb-tl', 'at-tl'), ('bem*', 'vbg'), ('fw-vb', ','), ('pp$-nc', 'nn-nc'), ('nns-tl-hl', ':-hl'), ('ppo-tl', "''"), ('dt-tl', 'nn-tl'), ('fw-nns-tl', 'fw-jj-tl'), ('np+bez', 'rb'), ('uh-tl', 'in-tl'), ('jjr-hl', 'nn-hl'), ('ap$', 'nns'), ('rb-nc', "''"), ('np+hvz', 'vbn'), ('vbd-nc', 'in-nc'), ('wrb+dod', 'ppss'), ("16''", "''"), ('ql-tl', 'jj-tl'), ('bedz-nc', 'at-nc'), ('fw-at+nn-tl', 'fw-jj-tl'), ('in-nc', 'nn-nc'), ('vbn-tl-hl', 'nns-tl-hl'), ('bed*', 'ql'), ('wrb+bez', 'np'), ('vb-nc', 'in-nc'), ('pp$-hl', 'nn-hl'), ('ppss-tl', 'md-tl'), ('wps+md', 'be'), ('od-hl', 'nn-hl'), ('uh-nc', "''"), ('jjt-tl', 'nn-tl'), ('fw-cc-tl', 'fw-n ...

# %%
# forming bigram model as list from test corpus
# seprating tags and words and counting each word tag pair for brown _test
q = []
for i in brown_test:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_test = [[]for i in range(x)]
for i in range(x):
    if i+1 < x:   
        bigram_test[i].append( q[i] )   
        bigram_test[i].append( q[i+1])
    
#print (bigram_test)   #bigram_test list have 49948

# %%
bigram_test
# Out:
# [[['The', 'at'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], ['Grand', 'jj-tl']],
#  [['Grand', 'jj-tl'], ['Jury', 'nn-tl']],
#  [['Jury', 'nn-tl'], ['said', 'vbd']],
#  [['said', 'vbd'], ['Friday', 'nr']],
#  [['Friday', 'nr'], ['an', 'at']],
#  [['an', 'at'], ['investigation', 'nn']],
#  [['investigation', 'nn'], ['of', 'in']],
#  [['of', 'in'], ["Atlanta's", 'np$']],
#  [["Atlanta's", 'np$'], ['recent', 'jj']],
#  [['recent', 'jj'], ['primary', 'nn']],
#  [['primary', 'nn'], ['election', 'nn']],
#  [['election', 'nn'], ['produced', 'vbd']],
#  [['produced', 'vbd'], ['``', '``']],
#  [['``', '``'], ['no', 'at']],
#  [['no', 'at'], ['evidence', 'nn']],
#  [['evidence', 'nn'], ["''", "''"]],
#  [["''", "''"], ['that', 'cs']],
#  [['that', 'cs'], ['any', 'dti']],
#  [['any', 'dti'], ['irregularities', 'nns']],
#  [['irregularities', 'nns'], ['took', 'vbd']],
#  [['took', 'vbd'], ['place', 'nn']],
#  [['place', 'nn'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['further', 'rbr']],
#  [['further', 'rbr'], ['said', 'vbd']],
#  [['said', 'vbd'], ['in', 'in']],
#  [['in', 'in'], ['term-end', 'nn']],
#  [['term-end', 'nn'], ['presentments', 'nns']],
#  [['presentments', 'nns'], ['that', 'cs']],
#  [['that', 'cs'], ['the', 'at']],
#  [['the', 'at'], ['City', 'nn-tl']],
#  [['City', 'nn-tl'], ['Executive', 'jj-tl']],
#  [['Executive', 'jj-tl'], ['Committee', 'nn-tl']],
#  [['Committee', 'nn-tl'], [',', ',']],
#  [[',', ','], ['which', 'wdt']],
#  [['which', 'wdt'], ['had', 'hvd']],
#  [['had', 'hvd'], ['over-all', 'jj']],
#  [['over-all', 'jj'], ['charge', 'nn']],
#  [['charge', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['election', 'nn']],
#  [['election', 'nn'], [',', ',']],
#  [[',', ','], ['``', '``']],
#  [['``', '``'], ['deserves', 'vbz']],
#  [['deserves', 'vbz'], ['the', 'at']],
#  [['the', 'at'], ['praise', 'nn']],
#  [['praise', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['thanks', 'nns']],
#  [['thanks', 'nns'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['City', 'nn-tl']],
#  [['City', 'nn-tl'], ['of', 'in-tl']],
#  [['of', 'in-tl'], ['Atlanta', 'np-tl']],
#  [['Atlanta', 'np-tl'], ["''", "''"]],
#  [["''", "''"], ['for', 'in']],
#  [['for', 'in'], ['the', 'at']],
#  [['the', 'at'], ['manner', 'nn']],
#  [['manner', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['which', 'wdt']],
#  [['which', 'wdt'], ['the', 'at']],
#  [['the', 'at'], ['election', 'nn']],
#  [['election', 'nn'], ['was', 'bedz']],
#  [['was', 'bedz'], ['conducted', 'vbn']],
#  [['conducted', 'vbn'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['September-October', 'np']],
#  [['September-October', 'np'], ['term', 'nn']],
#  [['term', 'nn'], ['jury', 'nn']],
#  [['jury', 'nn'], ['had', 'hvd']],
#  [['had', 'hvd'], ['been', 'ben']],
#  [['been', 'ben'], ['charged', 'vbn']],
#  [['charged', 'vbn'], ['by', 'in']],
#  [['by', 'in'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['Superior', 'jj-tl']],
#  [['Superior', 'jj-tl'], ['Court', 'nn-tl']],
#  [['Court', 'nn-tl'], ['Judge', 'nn-tl']],
#  [['Judge', 'nn-tl'], ['Durwood', 'np']],
#  [['Durwood', 'np'], ['Pye', 'np']],
#  [['Pye', 'np'], ['to', 'to']],
#  [['to', 'to'], ['investigate', 'vb']],
#  [['investigate', 'vb'], ['reports', 'nns']],
#  [['reports', 'nns'], ['of', 'in']],
#  [['of', 'in'], ['possible', 'jj']],
#  [['possible', 'jj'], ['``', '``']],
#  [['``', '``'], ['irregularities', 'nns']],
#  [['irregularities', 'nns'], ["''", "''"]],
#  [["''", "''"], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['hard-fought', 'jj']],
#  [['hard-fought', 'jj'], ['primary', 'nn']],
#  [['primary', 'nn'], ['which', 'wdt']],
#  [['which', 'wdt'], ['was', 'bedz']],
#  [['was', 'bedz'], ['won', 'vbn']],
#  [['won', 'vbn'], ['by', 'in']],
#  [['by', 'in'], ['Mayor-nominate', 'nn-tl']],
#  [['Mayor-nominate', 'nn-tl'], ['Ivan', 'np']],
#  [['Ivan', 'np'], ['Allen', 'np']],
#  [['Allen', 'np'], ['Jr.', 'np']],
#  [['Jr.', 'np'], ['.', '.']],
#  [['.', '.'], ['``', '``']],
#  [['``', '``'], ['Only', 'rb']],
#  [['Only', 'rb'], ['a', 'at']],
#  [['a', 'at'], ['relative', 'jj']],
#  [['relative', 'jj'], ['handful', 'nn']],
#  [['handful', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['such', 'jj']],
#  [['such', 'jj'], ['reports', 'nns']],
#  [['reports', 'nns'], ['was', 'bedz']],
#  [['was', 'bedz'], ['received', 'vbn']],
#  [['received', 'vbn'], ["''", "''"]],
#  [["''", "''"], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], [',', ',']],
#  [[',', ','], ['``', '``']],
#  [['``', '``'], ['considering', 'in']],
#  [['considering', 'in'], ['the', 'at']],
#  [['the', 'at'], ['widespread', 'jj']],
#  [['widespread', 'jj'], ['interest', 'nn']],
#  [['interest', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['election', 'nn']],
#  [['election', 'nn'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['number', 'nn']],
#  [['number', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['voters', 'nns']],
#  [['voters', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['the', 'at']],
#  [['the', 'at'], ['size', 'nn']],
#  [['size', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['this', 'dt']],
#  [['this', 'dt'], ['city', 'nn']],
#  [['city', 'nn'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['it', 'pps']],
#  [['it', 'pps'], ['did', 'dod']],
#  [['did', 'dod'], ['find', 'vb']],
#  [['find', 'vb'], ['that', 'cs']],
#  [['that', 'cs'], ['many', 'ap']],
#  [['many', 'ap'], ['of', 'in']],
#  [['of', 'in'], ["Georgia's", 'np$']],
#  [["Georgia's", 'np$'], ['registration', 'nn']],
#  [['registration', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['election', 'nn']],
#  [['election', 'nn'], ['laws', 'nns']],
#  [['laws', 'nns'], ['``', '``']],
#  [['``', '``'], ['are', 'ber']],
#  [['are', 'ber'], ['outmoded', 'jj']],
#  [['outmoded', 'jj'], ['or', 'cc']],
#  [['or', 'cc'], ['inadequate', 'jj']],
#  [['inadequate', 'jj'], ['and', 'cc']],
#  [['and', 'cc'], ['often', 'rb']],
#  [['often', 'rb'], ['ambiguous', 'jj']],
#  [['ambiguous', 'jj'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['It', 'pps']],
#  [['It', 'pps'], ['recommended', 'vbd']],
#  [['recommended', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['Fulton', 'np']],
#  [['Fulton', 'np'], ['legislators', 'nns']],
#  [['legislators', 'nns'], ['act', 'vb']],
#  [['act', 'vb'], ['``', '``']],
#  [['``', '``'], ['to', 'to']],
#  [['to', 'to'], ['have', 'hv']],
#  [['have', 'hv'], ['these', 'dts']],
#  [['these', 'dts'], ['laws', 'nns']],
#  [['laws', 'nns'], ['studied', 'vbn']],
#  [['studied', 'vbn'], ['and', 'cc']],
#  [['and', 'cc'], ['revised', 'vbn']],
#  [['revised', 'vbn'], ['to', 'in']],
#  [['to', 'in'], ['the', 'at']],
#  [['the', 'at'], ['end', 'nn']],
#  [['end', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['modernizing', 'vbg']],
#  [['modernizing', 'vbg'], ['and', 'cc']],
#  [['and', 'cc'], ['improving', 'vbg']],
#  [['improving', 'vbg'], ['them', 'ppo']],
#  [['them', 'ppo'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['grand', 'jj']],
#  [['grand', 'jj'], ['jury', 'nn']],
#  [['jury', 'nn'], ['commented', 'vbd']],
#  [['commented', 'vbd'], ['on', 'in']],
#  [['on', 'in'], ['a', 'at']],
#  [['a', 'at'], ['number', 'nn']],
#  [['number', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['other', 'ap']],
#  [['other', 'ap'], ['topics', 'nns']],
#  [['topics', 'nns'], [',', ',']],
#  [[',', ','], ['among', 'in']],
#  [['among', 'in'], ['them', 'ppo']],
#  [['them', 'ppo'], ['the', 'at']],
#  [['the', 'at'], ['Atlanta', 'np']],
#  [['Atlanta', 'np'], ['and', 'cc']],
#  [['and', 'cc'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], ['purchasing', 'vbg']],
#  [['purchasing', 'vbg'], ['departments', 'nns']],
#  [['departments', 'nns'], ['which', 'wdt']],
#  [['which', 'wdt'], ['it', 'pps']],
#  [['it', 'pps'], ['said', 'vbd']],
#  [['said', 'vbd'], ['``', '``']],
#  [['``', '``'], ['are', 'ber']],
#  [['are', 'ber'], ['well', 'ql']],
#  [['well', 'ql'], ['operated', 'vbn']],
#  [['operated', 'vbn'], ['and', 'cc']],
#  [['and', 'cc'], ['follow', 'vb']],
#  [['follow', 'vb'], ['generally', 'rb']],
#  [['generally', 'rb'], ['accepted', 'vbn']],
#  [['accepted', 'vbn'], ['practices', 'nns']],
#  [['practices', 'nns'], ['which', 'wdt']],
#  [['which', 'wdt'], ['inure', 'vb']],
#  [['inure', 'vb'], ['to', 'in']],
#  [['to', 'in'], ['the', 'at']],
#  [['the', 'at'], ['best', 'jjt']],
#  [['best', 'jjt'], ['interest', 'nn']],
#  [['interest', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['both', 'abx']],
#  [['both', 'abx'], ['governments', 'nns']],
#  [['governments', 'nns'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['Merger', 'nn-hl']],
#  [['Merger', 'nn-hl'], ['proposed', 'vbn-hl']],
#  [['proposed', 'vbn-hl'], ['However', 'wrb']],
#  [['However', 'wrb'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['it', 'pps']],
#  [['it', 'pps'], ['believes', 'vbz']],
#  [['believes', 'vbz'], ['``', '``']],
#  [['``', '``'], ['these', 'dts']],
#  [['these', 'dts'], ['two', 'cd']],
#  [['two', 'cd'], ['offices', 'nns']],
#  [['offices', 'nns'], ['should', 'md']],
#  [['should', 'md'], ['be', 'be']],
#  [['be', 'be'], ['combined', 'vbn']],
#  [['combined', 'vbn'], ['to', 'to']],
#  [['to', 'to'], ['achieve', 'vb']],
#  [['achieve', 'vb'], ['greater', 'jjr']],
#  [['greater', 'jjr'], ['efficiency', 'nn']],
#  [['efficiency', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['reduce', 'vb']],
#  [['reduce', 'vb'], ['the', 'at']],
#  [['the', 'at'], ['cost', 'nn']],
#  [['cost', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['administration', 'nn']],
#  [['administration', 'nn'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['City', 'nn-tl']],
#  [['City', 'nn-tl'], ['Purchasing', 'vbg-tl']],
#  [['Purchasing', 'vbg-tl'], ['Department', 'nn-tl']],
#  [['Department', 'nn-tl'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], [',', ',']],
#  [[',', ','], ['``', '``']],
#  [['``', '``'], ['is', 'bez']],
#  [['is', 'bez'], ['lacking', 'vbg']],
#  [['lacking', 'vbg'], ['in', 'in']],
#  [['in', 'in'], ['experienced', 'vbn']],
#  [['experienced', 'vbn'], ['clerical', 'jj']],
#  [['clerical', 'jj'], ['personnel', 'nns']],
#  [['personnel', 'nns'], ['as', 'cs']],
#  [['as', 'cs'], ['a', 'at']],
#  [['a', 'at'], ['result', 'nn']],
#  [['result', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['city', 'nn']],
#  [['city', 'nn'], ['personnel', 'nns']],
#  [['personnel', 'nns'], ['policies', 'nns']],
#  [['policies', 'nns'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['It', 'pps']],
#  [['It', 'pps'], ['urged', 'vbd']],
#  [['urged', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['the', 'at']],
#  [['the', 'at'], ['city', 'nn']],
#  [['city', 'nn'], ['``', '``']],
#  [['``', '``'], ['take', 'vb']],
#  [['take', 'vb'], ['steps', 'nns']],
#  [['steps', 'nns'], ['to', 'to']],
#  [['to', 'to'], ['remedy', 'vb']],
#  [['remedy', 'vb'], ["''", "''"]],
#  [["''", "''"], ['this', 'dt']],
#  [['this', 'dt'], ['problem', 'nn']],
#  [['problem', 'nn'], ['.', '.']],
#  [['.', '.'], ['Implementation', 'nn']],
#  [['Implementation', 'nn'], ['of', 'in']],
#  [['of', 'in'], ["Georgia's", 'np$']],
#  [["Georgia's", 'np$'], ['automobile', 'nn']],
#  [['automobile', 'nn'], ['title', 'nn']],
#  [['title', 'nn'], ['law', 'nn']],
#  [['law', 'nn'], ['was', 'bedz']],
#  [['was', 'bedz'], ['also', 'rb']],
#  [['also', 'rb'], ['recommended', 'vbn']],
#  [['recommended', 'vbn'], ['by', 'in']],
#  [['by', 'in'], ['the', 'at']],
#  [['the', 'at'], ['outgoing', 'jj']],
#  [['outgoing', 'jj'], ['jury', 'nn']],
#  [['jury', 'nn'], ['.', '.']],
#  [['.', '.'], ['It', 'pps']],
#  [['It', 'pps'], ['urged', 'vbd']],
#  [['urged', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['the', 'at']],
#  [['the', 'at'], ['next', 'ap']],
#  [['next', 'ap'], ['Legislature', 'nn-tl']],
#  [['Legislature', 'nn-tl'], ['``', '``']],
#  [['``', '``'], ['provide', 'vb']],
#  [['provide', 'vb'], ['enabling', 'vbg']],
#  [['enabling', 'vbg'], ['funds', 'nns']],
#  [['funds', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['re-set', 'vb']],
#  [['re-set', 'vb'], ['the', 'at']],
#  [['the', 'at'], ['effective', 'jj']],
#  [['effective', 'jj'], ['date', 'nn']],
#  [['date', 'nn'], ['so', 'cs']],
#  [['so', 'cs'], ['that', 'cs']],
#  [['that', 'cs'], ['an', 'at']],
#  [['an', 'at'], ['orderly', 'jj']],
#  [['orderly', 'jj'], ['implementation', 'nn']],
#  [['implementation', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['law', 'nn']],
#  [['law', 'nn'], ['may', 'md']],
#  [['may', 'md'], ['be', 'be']],
#  [['be', 'be'], ['effected', 'vbn']],
#  [['effected', 'vbn'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['grand', 'jj']],
#  [['grand', 'jj'], ['jury', 'nn']],
#  [['jury', 'nn'], ['took', 'vbd']],
#  [['took', 'vbd'], ['a', 'at']],
#  [['a', 'at'], ['swipe', 'nn']],
#  [['swipe', 'nn'], ['at', 'in']],
#  [['at', 'in'], ['the', 'at']],
#  [['the', 'at'], ['State', 'nn-tl']],
#  [['State', 'nn-tl'], ['Welfare', 'nn-tl']],
#  [['Welfare', 'nn-tl'], ["Department's", 'nn$-tl']],
#  [["Department's", 'nn$-tl'], ['handling', 'nn']],
#  [['handling', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['federal', 'jj']],
#  [['federal', 'jj'], ['funds', 'nns']],
#  [['funds', 'nns'], ['granted', 'vbn']],
#  [['granted', 'vbn'], ['for', 'in']],
#  [['for', 'in'], ['child', 'nn']],
#  [['child', 'nn'], ['welfare', 'nn']],
#  [['welfare', 'nn'], ['services', 'nns']],
#  [['services', 'nns'], ['in', 'in']],
#  [['in', 'in'], ['foster', 'jj']],
#  [['foster', 'jj'], ['homes', 'nns']],
#  [['homes', 'nns'], ['.', '.']],
#  [['.', '.'], ['``', '``']],
#  [['``', '``'], ['This', 'dt']],
#  [['This', 'dt'], ['is', 'bez']],
#  [['is', 'bez'], ['one', 'cd']],
#  [['one', 'cd'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['major', 'jj']],
#  [['major', 'jj'], ['items', 'nns']],
#  [['items', 'nns'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], ['general', 'jj']],
#  [['general', 'jj'], ['assistance', 'nn']],
#  [['assistance', 'nn'], ['program', 'nn']],
#  [['program', 'nn'], ["''", "''"]],
#  [["''", "''"], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], [',', ',']],
#  [[',', ','], ['but', 'cc']],
#  [['but', 'cc'], ['the', 'at']],
#  [['the', 'at'], ['State', 'nn-tl']],
#  [['State', 'nn-tl'], ['Welfare', 'nn-tl']],
#  [['Welfare', 'nn-tl'], ['Department', 'nn-tl']],
#  [['Department', 'nn-tl'], ['``', '``']],
#  [['``', '``'], ['has', 'hvz']],
#  [['has', 'hvz'], ['seen', 'vbn']],
#  [['seen', 'vbn'], ['fit', 'jj']],
#  [['fit', 'jj'], ['to', 'to']],
#  [['to', 'to'], ['distribute', 'vb']],
#  [['distribute', 'vb'], ['these', 'dts']],
#  [['these', 'dts'], ['funds', 'nns']],
#  [['funds', 'nns'], ['through', 'in']],
#  [['through', 'in'], ['the', 'at']],
#  [['the', 'at'], ['welfare', 'nn']],
#  [['welfare', 'nn'], ['departments', 'nns']],
#  [['departments', 'nns'], ['of', 'in']],
#  [['of', 'in'], ['all', 'abn']],
#  [['all', 'abn'], ['the', 'at']],
#  [['the', 'at'], ['counties', 'nns']],
#  [['counties', 'nns'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['state', 'nn']],
#  [['state', 'nn'], ['with', 'in']],
#  [['with', 'in'], ['the', 'at']],
#  [['the', 'at'], ['exception', 'nn']],
#  [['exception', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], [',', ',']],
#  [[',', ','], ['which', 'wdt']],
#  [['which', 'wdt'], ['receives', 'vbz']],
#  [['receives', 'vbz'], ['none', 'pn']],
#  [['none', 'pn'], ['of', 'in']],
#  [['of', 'in'], ['this', 'dt']],
#  [['this', 'dt'], ['money', 'nn']],
#  [['money', 'nn'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jurors', 'nns']],
#  [['jurors', 'nns'], ['said', 'vbd']],
#  [['said', 'vbd'], ['they', 'ppss']],
#  [['they', 'ppss'], ['realize', 'vb']],
#  [['realize', 'vb'], ['``', '``']],
#  [['``', '``'], ['a', 'at']],
#  [['a', 'at'], ['proportionate', 'jj']],
#  [['proportionate', 'jj'], ['distribution', 'nn']],
#  [['distribution', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['these', 'dts']],
#  [['these', 'dts'], ['funds', 'nns']],
#  [['funds', 'nns'], ['might', 'md']],
#  [['might', 'md'], ['disable', 'vb']],
#  [['disable', 'vb'], ['this', 'dt']],
#  [['this', 'dt'], ['program', 'nn']],
#  [['program', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['our', 'pp$']],
#  [['our', 'pp$'], ['less', 'ql']],
#  [['less', 'ql'], ['populous', 'jj']],
#  [['populous', 'jj'], ['counties', 'nns']],
#  [['counties', 'nns'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['Nevertheless', 'rb']],
#  [['Nevertheless', 'rb'], [',', ',']],
#  [[',', ','], ['``', '``']],
#  [['``', '``'], ['we', 'ppss']],
#  [['we', 'ppss'], ['feel', 'vb']],
#  [['feel', 'vb'], ['that', 'cs']],
#  [['that', 'cs'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['future', 'nn']],
#  [['future', 'nn'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], ['should', 'md']],
#  [['should', 'md'], ['receive', 'vb']],
#  [['receive', 'vb'], ['some', 'dti']],
#  [['some', 'dti'], ['portion', 'nn']],
#  [['portion', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['these', 'dts']],
#  [['these', 'dts'], ['available', 'jj']],
#  [['available', 'jj'], ['funds', 'nns']],
#  [['funds', 'nns'], ["''", "''"]],
#  [["''", "''"], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jurors', 'nns']],
#  [['jurors', 'nns'], ['said', 'vbd']],
#  [['said', 'vbd'], ['.', '.']],
#  [['.', '.'], ['``', '``']],
#  [['``', '``'], ['Failure', 'nn']],
#  [['Failure', 'nn'], ['to', 'to']],
#  [['to', 'to'], ['do', 'do']],
#  [['do', 'do'], ['this', 'dt']],
#  [['this', 'dt'], ['will', 'md']],
#  [['will', 'md'], ['continue', 'vb']],
#  [['continue', 'vb'], ['to', 'to']],
#  [['to', 'to'], ['place', 'vb']],
#  [['place', 'vb'], ['a', 'at']],
#  [['a', 'at'], ['disproportionate', 'jj']],
#  [['disproportionate', 'jj'], ['burden', 'nn']],
#  [['burden', 'nn'], ["''", "''"]],
#  [["''", "''"], ['on', 'in']],
#  [['on', 'in'], ['Fulton', 'np']],
#  [['Fulton', 'np'], ['taxpayers', 'nns']],
#  [['taxpayers', 'nns'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['also', 'rb']],
#  [['also', 'rb'], ['commented', 'vbd']],
#  [['commented', 'vbd'], ['on', 'in']],
#  [['on', 'in'], ['the', 'at']],
#  [['the', 'at'], ['Fulton', 'np']],
#  [['Fulton', 'np'], ["ordinary's", 'nn$']],
#  [["ordinary's", 'nn$'], ['court', 'nn']],
#  [['court', 'nn'], ['which', 'wdt']],
#  [['which', 'wdt'], ['has', 'hvz']],
#  [['has', 'hvz'], ['been', 'ben']],
#  [['been', 'ben'], ['under', 'in']],
#  [['under', 'in'], ['fire', 'nn']],
#  [['fire', 'nn'], ['for', 'in']],
#  [['for', 'in'], ['its', 'pp$']],
#  [['its', 'pp$'], ['practices', 'nns']],
#  [['practices', 'nns'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['appointment', 'nn']],
#  [['appointment', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['appraisers', 'nns']],
#  [['appraisers', 'nns'], [',', ',']],
#  [[',', ','], ['guardians', 'nns']],
#  [['guardians', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['administrators', 'nns']],
#  [['administrators', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['the', 'at']],
#  [['the', 'at'], ['awarding', 'nn']],
#  [['awarding', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['fees', 'nns']],
#  [['fees', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['compensation', 'nn']],
#  [['compensation', 'nn'], ['.', '.']],
#  [['.', '.'], ['Wards', 'nns-hl']],
#  [['Wards', 'nns-hl'], ['protected', 'vbn-hl']],
#  [['protected', 'vbn-hl'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['it', 'pps']],
#  [['it', 'pps'], ['found', 'vbd']],
#  [['found', 'vbd'], ['the', 'at']],
#  [['the', 'at'], ['court', 'nn']],
#  [['court', 'nn'], ['``', '``']],
#  [['``', '``'], ['has', 'hvz']],
#  [['has', 'hvz'], ['incorporated', 'vbn']],
#  [['incorporated', 'vbn'], ['into', 'in']],
#  [['into', 'in'], ['its', 'pp$']],
#  [['its', 'pp$'], ['operating', 'vbg']],
#  [['operating', 'vbg'], ['procedures', 'nns']],
#  [['procedures', 'nns'], ['the', 'at']],
#  [['the', 'at'], ['recommendations', 'nns']],
#  [['recommendations', 'nns'], ["''", "''"]],
#  [["''", "''"], ['of', 'in']],
#  [['of', 'in'], ['two', 'cd']],
#  [['two', 'cd'], ['previous', 'jj']],
#  [['previous', 'jj'], ['grand', 'jj']],
#  [['grand', 'jj'], ['juries', 'nns']],
#  [['juries', 'nns'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['Atlanta', 'np-tl']],
#  [['Atlanta', 'np-tl'], ['Bar', 'nn-tl']],
#  [['Bar', 'nn-tl'], ['Association', 'nn-tl']],
#  [['Association', 'nn-tl'], ['and', 'cc']],
#  [['and', 'cc'], ['an', 'at']],
#  [['an', 'at'], ['interim', 'nn']],
#  [['interim', 'nn'], ['citizens', 'nns']],
#  [['citizens', 'nns'], ['committee', 'nn']],
#  [['committee', 'nn'], ['.', '.']],
#  [['.', '.'], ['``', '``']],
#  [['``', '``'], ['These', 'dts']],
#  [['These', 'dts'], ['actions', 'nns']],
#  [['actions', 'nns'], ['should', 'md']],
#  [['should', 'md'], ['serve', 'vb']],
#  [['serve', 'vb'], ['to', 'to']],
#  [['to', 'to'], ['protect', 'vb']],
#  [['protect', 'vb'], ['in', 'in']],
#  [['in', 'in'], ['fact', 'nn']],
#  [['fact', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['in', 'in']],
#  [['in', 'in'], ['effect', 'nn']],
#  [['effect', 'nn'], ['the', 'at']],
#  [['the', 'at'], ["court's", 'nn$']],
#  [["court's", 'nn$'], ['wards', 'nns']],
#  [['wards', 'nns'], ['from', 'in']],
#  [['from', 'in'], ['undue', 'jj']],
#  [['undue', 'jj'], ['costs', 'nns']],
#  [['costs', 'nns'], ['and', 'cc']],
#  [['and', 'cc'], ['its', 'pp$']],
#  [['its', 'pp$'], ['appointed', 'vbn']],
#  [['appointed', 'vbn'], ['and', 'cc']],
#  [['and', 'cc'], ['elected', 'vbn']],
#  [['elected', 'vbn'], ['servants', 'nns']],
#  [['servants', 'nns'], ['from', 'in']],
#  [['from', 'in'], ['unmeritorious', 'jj']],
#  [['unmeritorious', 'jj'], ['criticisms', 'nns']],
#  [['criticisms', 'nns'], ["''", "''"]],
#  [["''", "''"], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['.', '.']],
#  [['.', '.'], ['Regarding', 'in']],
#  [['Regarding', 'in'], ["Atlanta's", 'np$']],
#  [["Atlanta's", 'np$'], ['new', 'jj']],
#  [['new', 'jj'], ['multi-million-dollar', 'jj']],
#  [['multi-million-dollar', 'jj'], ['airport', 'nn']],
#  [['airport', 'nn'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['recommended', 'vbd']],
#  [['recommended', 'vbd'], ['``', '``']],
#  [['``', '``'], ['that', 'cs']],
#  [['that', 'cs'], ['when', 'wrb']],
#  [['when', 'wrb'], ['the', 'at']],
#  [['the', 'at'], ['new', 'jj']],
#  [['new', 'jj'], ['management', 'nn']],
#  [['management', 'nn'], ['takes', 'vbz']],
#  [['takes', 'vbz'], ['charge', 'nn']],
#  [['charge', 'nn'], ['Jan.', 'np']],
#  [['Jan.', 'np'], ['1', 'cd']],
#  [['1', 'cd'], ['the', 'at']],
#  [['the', 'at'], ['airport', 'nn']],
#  [['airport', 'nn'], ['be', 'be']],
#  [['be', 'be'], ['operated', 'vbn']],
#  [['operated', 'vbn'], ['in', 'in']],
#  [['in', 'in'], ['a', 'at']],
#  [['a', 'at'], ['manner', 'nn']],
#  [['manner', 'nn'], ['that', 'wps']],
#  [['that', 'wps'], ['will', 'md']],
#  [['will', 'md'], ['eliminate', 'vb']],
#  [['eliminate', 'vb'], ['political', 'jj']],
#  [['political', 'jj'], ['influences', 'nns']],
#  [['influences', 'nns'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['did', 'dod']],
#  [['did', 'dod'], ['not', '*']],
#  [['not', '*'], ['elaborate', 'vb']],
#  [['elaborate', 'vb'], [',', ',']],
#  [[',', ','], ['but', 'cc']],
#  [['but', 'cc'], ['it', 'pps']],
#  [['it', 'pps'], ['added', 'vbd']],
#  [['added', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['``', '``']],
#  [['``', '``'], ['there', 'ex']],
#  [['there', 'ex'], ['should', 'md']],
#  [['should', 'md'], ['be', 'be']],
#  [['be', 'be'], ['periodic', 'jj']],
#  [['periodic', 'jj'], ['surveillance', 'nn']],
#  [['surveillance', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['pricing', 'vbg']],
#  [['pricing', 'vbg'], ['practices', 'nns']],
#  [['practices', 'nns'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['concessionaires', 'nns']],
#  [['concessionaires', 'nns'], ['for', 'in']],
#  [['for', 'in'], ['the', 'at']],
#  [['the', 'at'], ['purpose', 'nn']],
#  [['purpose', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['keeping', 'vbg']],
#  [['keeping', 'vbg'], ['the', 'at']],
#  [['the', 'at'], ['prices', 'nns']],
#  [['prices', 'nns'], ['reasonable', 'jj']],
#  [['reasonable', 'jj'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['Ask', 'vb-hl']],
#  [['Ask', 'vb-hl'], ['jail', 'nn-hl']],
#  [['jail', 'nn-hl'], ['deputies', 'nns-hl']],
#  [['deputies', 'nns-hl'], ['On', 'in']],
#  [['On', 'in'], ['other', 'ap']],
#  [['other', 'ap'], ['matters', 'nns']],
#  [['matters', 'nns'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['recommended', 'vbd']],
#  [['recommended', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], [':', ':']],
#  [[':', ':'], ['(', '(']],
#  [['(', '('], ['1', 'cd']],
#  [['1', 'cd'], [')', ')']],
#  [[')', ')'], ['Four', 'cd']],
#  [['Four', 'cd'], ['additional', 'jj']],
#  [['additional', 'jj'], ['deputies', 'nns']],
#  [['deputies', 'nns'], ['be', 'be']],
#  [['be', 'be'], ['employed', 'vbn']],
#  [['employed', 'vbn'], ['at', 'in']],
#  [['at', 'in'], ['the', 'at']],
#  [['the', 'at'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['County', 'nn-tl']],
#  [['County', 'nn-tl'], ['Jail', 'nn-tl']],
#  [['Jail', 'nn-tl'], ['and', 'cc']],
#  [['and', 'cc'], ['``', '``']],
#  [['``', '``'], ['a', 'at']],
#  [['a', 'at'], ['doctor', 'nn']],
#  [['doctor', 'nn'], [',', ',']],
#  [[',', ','], ['medical', 'jj']],
#  [['medical', 'jj'], ['intern', 'nn']],
#  [['intern', 'nn'], ['or', 'cc']],
#  [['or', 'cc'], ['extern', 'nn']],
#  [['extern', 'nn'], ['be', 'be']],
#  [['be', 'be'], ['employed', 'vbn']],
#  [['employed', 'vbn'], ['for', 'in']],
#  [['for', 'in'], ['night', 'nn']],
#  [['night', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['weekend', 'nn']],
#  [['weekend', 'nn'], ['duty', 'nn']],
#  [['duty', 'nn'], ['at', 'in']],
#  [['at', 'in'], ['the', 'at']],
#  [['the', 'at'], ['jail', 'nn']],
#  [['jail', 'nn'], ["''", "''"]],
#  [["''", "''"], ['.', '.']],
#  [['.', '.'], ['(', '(']],
#  [['(', '('], ['2', 'cd']],
#  [['2', 'cd'], [')', ')']],
#  [[')', ')'], ['Fulton', 'np']],
#  [['Fulton', 'np'], ['legislators', 'nns']],
#  [['legislators', 'nns'], ['``', '``']],
#  [['``', '``'], ['work', 'vb']],
#  [['work', 'vb'], ['with', 'in']],
#  [['with', 'in'], ['city', 'nn']],
#  [['city', 'nn'], ['officials', 'nns']],
#  [['officials', 'nns'], ['to', 'to']],
#  [['to', 'to'], ['pass', 'vb']],
#  [['pass', 'vb'], ['enabling', 'vbg']],
#  [['enabling', 'vbg'], ['legislation', 'nn']],
#  [['legislation', 'nn'], ['that', 'wps']],
#  [['that', 'wps'], ['will', 'md']],
#  [['will', 'md'], ['permit', 'vb']],
#  [['permit', 'vb'], ['the', 'at']],
#  [['the', 'at'], ['establishment', 'nn']],
#  [['establishment', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['a', 'at']],
#  [['a', 'at'], ['fair', 'jj']],
#  [['fair', 'jj'], ['and', 'cc']],
#  [['and', 'cc'], ['equitable', 'jj']],
#  [['equitable', 'jj'], ["''", "''"]],
#  [["''", "''"], ['pension', 'nn']],
#  [['pension', 'nn'], ['plan', 'nn']],
#  [['plan', 'nn'], ['for', 'in']],
#  [['for', 'in'], ['city', 'nn']],
#  [['city', 'nn'], ['employes', 'nns']],
#  [['employes', 'nns'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['jury', 'nn']],
#  [['jury', 'nn'], ['praised', 'vbd']],
#  [['praised', 'vbd'], ['the', 'at']],
#  [['the', 'at'], ['administration', 'nn']],
#  [['administration', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['operation', 'nn']],
#  [['operation', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['the', 'at']],
#  [['the', 'at'], ['Atlanta', 'np-tl']],
#  [['Atlanta', 'np-tl'], ['Police', 'nns-tl']],
#  [['Police', 'nns-tl'], ['Department', 'nn-tl']],
#  [['Department', 'nn-tl'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['Tax', 'nn-tl']],
#  [['Tax', 'nn-tl'], ["Commissioner's", 'nn$-tl']],
#  [["Commissioner's", 'nn$-tl'], ['Office', 'nn-tl']],
#  [['Office', 'nn-tl'], [',', ',']],
#  [[',', ','], ['the', 'at']],
#  [['the', 'at'], ['Bellwood', 'np']],
#  [['Bellwood', 'np'], ['and', 'cc']],
#  [['and', 'cc'], ['Alpharetta', 'np']],
#  [['Alpharetta', 'np'], ['prison', 'nn']],
#  [['prison', 'nn'], ['farms', 'nns']],
#  [['farms', 'nns'], [',', ',']],
#  [[',', ','], ['Grady', 'np-tl']],
#  [['Grady', 'np-tl'], ['Hospital', 'nn-tl']],
#  [['Hospital', 'nn-tl'], ['and', 'cc']],
#  [['and', 'cc'], ['the', 'at']],
#  [['the', 'at'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['Health', 'nn-tl']],
#  [['Health', 'nn-tl'], ['Department', 'nn-tl']],
#  [['Department', 'nn-tl'], ['.', '.']],
#  [['.', '.'], ['Mayor', 'nn-tl']],
#  [['Mayor', 'nn-tl'], ['William', 'np']],
#  [['William', 'np'], ['B.', 'np']],
#  [['B.', 'np'], ['Hartsfield', 'np']],
#  [['Hartsfield', 'np'], ['filed', 'vbd']],
#  [['filed', 'vbd'], ['suit', 'nn']],
#  [['suit', 'nn'], ['for', 'in']],
#  [['for', 'in'], ['divorce', 'nn']],
#  [['divorce', 'nn'], ['from', 'in']],
#  [['from', 'in'], ['his', 'pp$']],
#  [['his', 'pp$'], ['wife', 'nn']],
#  [['wife', 'nn'], [',', ',']],
#  [[',', ','], ['Pearl', 'np']],
#  [['Pearl', 'np'], ['Williams', 'np']],
#  [['Williams', 'np'], ['Hartsfield', 'np']],
#  [['Hartsfield', 'np'], [',', ',']],
#  [[',', ','], ['in', 'in']],
#  [['in', 'in'], ['Fulton', 'np-tl']],
#  [['Fulton', 'np-tl'], ['Superior', 'jj-tl']],
#  [['Superior', 'jj-tl'], ['Court', 'nn-tl']],
#  [['Court', 'nn-tl'], ['Friday', 'nr']],
#  [['Friday', 'nr'], ['.', '.']],
#  [['.', '.'], ['His', 'pp$']],
#  [['His', 'pp$'], ['petition', 'nn']],
#  [['petition', 'nn'], ['charged', 'vbd']],
#  [['charged', 'vbd'], ['mental', 'jj']],
#  [['mental', 'jj'], ['cruelty', 'nn']],
#  [['cruelty', 'nn'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['couple', 'nn']],
#  [['couple', 'nn'], ['was', 'bedz']],
#  [['was', 'bedz'], ['married', 'vbn']],
#  [['married', 'vbn'], ['Aug.', 'np']],
#  [['Aug.', 'np'], ['2', 'cd']],
#  [['2', 'cd'], [',', ',']],
#  [[',', ','], ['1913', 'cd']],
#  [['1913', 'cd'], ['.', '.']],
#  [['.', '.'], ['They', 'ppss']],
#  [['They', 'ppss'], ['have', 'hv']],
#  [['have', 'hv'], ['a', 'at']],
#  [['a', 'at'], ['son', 'nn']],
#  [['son', 'nn'], [',', ',']],
#  [[',', ','], ['William', 'np']],
#  [['William', 'np'], ['Berry', 'np']],
#  [['Berry', 'np'], ['Jr.', 'np']],
#  [['Jr.', 'np'], [',', ',']],
#  [[',', ','], ['and', 'cc']],
#  [['and', 'cc'], ['a', 'at']],
#  [['a', 'at'], ['daughter', 'nn']],
#  [['daughter', 'nn'], [',', ',']],
#  [[',', ','], ['Mrs.', 'np']],
#  [['Mrs.', 'np'], ['J.', 'np']],
#  [['J.', 'np'], ['M.', 'np']],
#  [['M.', 'np'], ['Cheshire', 'np']],
#  [['Cheshire', 'np'], ['of', 'in']],
#  [['of', 'in'], ['Griffin', 'np']],
#  [['Griffin', 'np'], ['.', '.']],
#  [['.', '.'], ['Attorneys', 'nns']],
#  [['Attorneys', 'nns'], ['for', 'in']],
#  [['for', 'in'], ['the', 'at']],
#  [['the', 'at'], ['mayor', 'nn']],
#  [['mayor', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['an', 'at']],
#  [['an', 'at'], ['amicable', 'jj']],
#  [['amicable', 'jj'], ['property', 'nn']],
#  [['property', 'nn'], ['settlement', 'nn']],
#  [['settlement', 'nn'], ['has', 'hvz']],
#  [['has', 'hvz'], ['been', 'ben']],
#  [['been', 'ben'], ['agreed', 'vbn']],
#  [['agreed', 'vbn'], ['upon', 'rb']],
#  [['upon', 'rb'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['petition', 'nn']],
#  [['petition', 'nn'], ['listed', 'vbd']],
#  [['listed', 'vbd'], ['the', 'at']],
#  [['the', 'at'], ["mayor's", 'nn$']],
#  [["mayor's", 'nn$'], ['occupation', 'nn']],
#  [['occupation', 'nn'], ['as', 'cs']],
#  [['as', 'cs'], ['``', '``']],
#  [['``', '``'], ['attorney', 'nn']],
#  [['attorney', 'nn'], ["''", "''"]],
#  [["''", "''"], ['and', 'cc']],
#  [['and', 'cc'], ['his', 'pp$']],
#  [['his', 'pp$'], ['age', 'nn']],
#  [['age', 'nn'], ['as', 'cs']],
#  [['as', 'cs'], ['71', 'cd']],
#  [['71', 'cd'], ['.', '.']],
#  [['.', '.'], ['It', 'pps']],
#  [['It', 'pps'], ['listed', 'vbd']],
#  [['listed', 'vbd'], ['his', 'pp$']],
#  [['his', 'pp$'], ["wife's", 'nn$']],
#  [["wife's", 'nn$'], ['age', 'nn']],
#  [['age', 'nn'], ['as', 'cs']],
#  [['as', 'cs'], ['74', 'cd']],
#  [['74', 'cd'], ['and', 'cc']],
#  [['and', 'cc'], ['place', 'nn']],
#  [['place', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['birth', 'nn']],
#  [['birth', 'nn'], ['as', 'cs']],
#  [['as', 'cs'], ['Opelika', 'np']],
#  [['Opelika', 'np'], [',', ',']],
#  [[',', ','], ['Ala.', 'np']],
#  [['Ala.', 'np'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['petition', 'nn']],
#  [['petition', 'nn'], ['said', 'vbd']],
#  [['said', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['the', 'at']],
#  [['the', 'at'], ['couple', 'nn']],
#  [['couple', 'nn'], ['has', 'hvz']],
#  [['has', 'hvz'], ['not', '*']],
#  [['not', '*'], ['lived', 'vbn']],
#  [['lived', 'vbn'], ['together', 'rb']],
#  [['together', 'rb'], ['as', 'cs']],
#  [['as', 'cs'], ['man', 'nn']],
#  [['man', 'nn'], ['and', 'cc']],
#  [['and', 'cc'], ['wife', 'nn']],
#  [['wife', 'nn'], ['for', 'in']],
#  [['for', 'in'], ['more', 'ap']],
#  [['more', 'ap'], ['than', 'in']],
#  [['than', 'in'], ['a', 'at']],
#  [['a', 'at'], ['year', 'nn']],
#  [['year', 'nn'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ['Hartsfield', 'np']],
#  [['Hartsfield', 'np'], ['home', 'nr']],
#  [['home', 'nr'], ['is', 'bez']],
#  [['is', 'bez'], ['at', 'in']],
#  [['at', 'in'], ['637', 'cd']],
#  [['637', 'cd'], ['E.', 'np']],
#  [['E.', 'np'], ['Pelham', 'np']],
#  [['Pelham', 'np'], ['Rd.', 'nn-tl']],
#  [['Rd.', 'nn-tl'], ['Aj', 'nn']],
#  [['Aj', 'nn'], ['.', '.']],
#  [['.', '.'], ['Henry', 'np']],
#  [['Henry', 'np'], ['L.', 'np']],
#  [['L.', 'np'], ['Bowden', 'np']],
#  [['Bowden', 'np'], ['was', 'bedz']],
#  [['was', 'bedz'], ['listed', 'vbn']],
#  [['listed', 'vbn'], ['on', 'in']],
#  [['on', 'in'], ['the', 'at']],
#  [['the', 'at'], ['petition', 'nn']],
#  [['petition', 'nn'], ['as', 'cs']],
#  [['as', 'cs'], ['the', 'at']],
#  [['the', 'at'], ["mayor's", 'nn$']],
#  [["mayor's", 'nn$'], ['attorney', 'nn']],
#  [['attorney', 'nn'], ['.', '.']],
#  [['.', '.'], ['Hartsfield', 'np']],
#  [['Hartsfield', 'np'], ['has', 'hvz']],
#  [['has', 'hvz'], ['been', 'ben']],
#  [['been', 'ben'], ['mayor', 'nn']],
#  [['mayor', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['Atlanta', 'np']],
#  [['Atlanta', 'np'], [',', ',']],
#  [[',', ','], ['with', 'in']],
#  [['with', 'in'], ['exception', 'nn']],
#  [['exception', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['one', 'cd']],
#  [['one', 'cd'], ['brief', 'jj']],
#  [['brief', 'jj'], ['interlude', 'nn']],
#  [['interlude', 'nn'], [',', ',']],
#  [[',', ','], ['since', 'in']],
#  [['since', 'in'], ['1937', 'cd']],
#  [['1937', 'cd'], ['.', '.']],
#  [['.', '.'], ['His', 'pp$']],
#  [['His', 'pp$'], ['political', 'jj']],
#  [['political', 'jj'], ['career', 'nn']],
#  [['career', 'nn'], ['goes', 'vbz']],
#  [['goes', 'vbz'], ['back', 'rb']],
#  [['back', 'rb'], ['to', 'in']],
#  [['to', 'in'], ['his', 'pp$']],
#  [['his', 'pp$'], ['election', 'nn']],
#  [['election', 'nn'], ['to', 'in']],
#  [['to', 'in'], ['city', 'nn']],
#  [['city', 'nn'], ['council', 'nn']],
#  [['council', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['1923', 'cd']],
#  [['1923', 'cd'], ['.', '.']],
#  [['.', '.'], ['The', 'at']],
#  [['The', 'at'], ["mayor's", 'nn$']],
#  [["mayor's", 'nn$'], ['present', 'jj']],
#  [['present', 'jj'], ['term', 'nn']],
#  [['term', 'nn'], ['of', 'in']],
#  [['of', 'in'], ['office', 'nn']],
#  [['office', 'nn'], ['expires', 'vbz']],
#  [['expires', 'vbz'], ['Jan.', 'np']],
#  [['Jan.', 'np'], ['1', 'cd']],
#  [['1', 'cd'], ['.', '.']],
#  [['.', '.'], ['He', 'pps']],
#  [['He', 'pps'], ['will', 'md']],
#  [['will', 'md'], ['be', 'be']],
#  [['be', 'be'], ['succeeded', 'vbn']],
#  [['succeeded', 'vbn'], ['by', 'in']],
#  [['by', 'in'], ['Ivan', 'np']],
#  [['Ivan', 'np'], ['Allen', 'np']],
#  [['Allen', 'np'], ['Jr.', 'np']],
#  [['Jr.', 'np'], [',', ',']],
#  [[',', ','], ['who', 'wps']],
#  [['who', 'wps'], ['became', 'vbd']],
#  [['became', 'vbd'], ['a', 'at']],
#  [['a', 'at'], ['candidate', 'nn']],
#  [['candidate', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['Sept.', 'np']],
#  [['Sept.', 'np'], ['13', 'cd']],
#  [['13', 'cd'], ['primary', 'nn']],
#  [['primary', 'nn'], ['after', 'cs']],
#  [['after', 'cs'], ['Mayor', 'nn-tl']],
#  [['Mayor', 'nn-tl'], ['Hartsfield', 'np']],
#  [['Hartsfield', 'np'], ['announced', 'vbd']],
#  [['announced', 'vbd'], ['that', 'cs']],
#  [['that', 'cs'], ['he', 'pps']],
#  [['he', 'pps'], ['would', 'md']],
#  [['would', 'md'], ['not', '*']],
#  [['not', '*'], ['run', 'vb']],
#  [['run', 'vb'], ['for', 'in']],
#  [['for', 'in'], ['reelection', 'nn']],
#  [['reelection', 'nn'], ['.', '.']],
#  [['.', '.'], ['Georgia', 'np']],
#  [['Georgia', 'np'], ['Republicans', 'nps']],
#  [['Republicans', 'nps'], ['are', 'ber']],
#  [['are', 'ber'], ['getting', 'vbg']],
#  [['getting', 'vbg'], ['strong', 'jj']],
#  [['strong', 'jj'], ['encouragement', 'nn']],
#  [['encouragement', 'nn'], ['to', 'to']],
#  [['to', 'to'], ['enter', 'vb']],
#  [['enter', 'vb'], ['a', 'at']],
#  [['a', 'at'], ['candidate', 'nn']],
#  [['candidate', 'nn'], ['in', 'in']],
#  [['in', 'in'], ['the', 'at']],
#  [['the', 'at'], ['1962', 'cd']],
#  [['1962', 'cd'], ["governor's", 'nn$']],
#  [["governor's", 'nn$'], ['race', 'nn']],
#  ...]

# %%
#bigram tagger  predictions for test set from training corpus

bigram_tag = []
x = len(bigram_test)
y = len(bi_max_fre_word_tag)
for i in range(x-1):
    g = bigram_test[i][0][1]
    for l in range(y): 
        if (g == bi_max_fre_word_tag[l][0]):
            temp = [bigram_test[i] , bi_max_fre_word_tag[l][1]]
            bigram_tag.append(temp)
            break;

print(bigram_tag)  # bigram_tag = [[[word,tag],[word,tag]], predicted tag]
# here we are considering only previous tag for bigram so unknown word will get tagged based there previous tag by MLE of tags
# Out:
# [[[['The', 'at'], ['Fulton', 'np-tl']], 'nn'], [[['Fulton', 'np-tl'], ['County', 'nn-tl']], 'nn-tl'], [[['County', 'nn-tl'], ['Grand', 'jj-tl']], 'nn-tl'], [[['Grand', 'jj-tl'], ['Jury', 'nn-tl']], 'nn-tl'], [[['Jury', 'nn-tl'], ['said', 'vbd']], 'nn-tl'], [[['said', 'vbd'], ['Friday', 'nr']], 'in'], [[['Friday', 'nr'], ['an', 'at']], 'in'], [[['an', 'at'], ['investigation', 'nn']], 'nn'], [[['investigation', 'nn'], ['of', 'in']], 'in'], [[['of', 'in'], ["Atlanta's", 'np$']], 'at'], [[["Atlanta's", 'np$'], ['recent', 'jj']], 'nn'], [[['recent', 'jj'], ['primary', 'nn']], 'nn'], [[['primary', 'nn'], ['election', 'nn']], 'in'], [[['election', 'nn'], ['produced', 'vbd']], 'in'], [[['produced', 'vbd'], ['``', '``']], 'in'], [[['``', '``'], ['no', 'at']], 'ppss'], [[['no', 'at'], ['evidence', 'nn']], 'nn'], [[['evidence', 'nn'], ["''", "''"]], 'in'], [[["''", "''"], ['that', 'cs']], '.'], [[['that', 'cs'], ['any', 'dti']], 'at'], [[['any', 'dti'], ['irregularities', 'nns']], 'nn'], [[['irregularities', 'nns'], ['took', 'vbd']], 'in'], [[['took', 'vbd'], ['place', 'nn']], 'in'], [[['place', 'nn'], ['.', '.']], 'in'], [[['.', '.'], ['The', 'at']], 'at'], [[['The', 'at'], ['jury', 'nn']], 'nn'], [[['jury', 'nn'], ['further', 'rbr']], 'in'], [[['further', 'rbr'], ['said', 'vbd']], ','], [[['said', 'vbd'], ['in', 'in']], 'in'], [[['in', 'in'], ['term-end', 'nn']], 'at'], [[['term-end', 'nn'], ['presentments', 'nns']], 'in'], [[['presentments', 'nns'], ['that', 'cs']], 'in'], [[['that', 'cs'], ['the', 'at']], 'at'], [[['the', 'at'], ['City', 'nn-tl']], 'nn'], [[['City', 'nn-tl'], ['Executive', 'jj-tl']], 'nn-tl'], [[['Executive', 'jj-tl'], ['Committee', 'nn-tl']], 'nn-tl'], [[['Committee', 'nn-tl'], [',', ',']], 'nn-tl'], [[[',', ','], ['which', 'wdt']], 'cc'], [[['which', 'wdt'], ['had', 'hvd']], 'ppss'], [[['had', 'hvd'], ['over-all', 'jj']], 'vbn'], [[['over-all', 'jj'], ['charge', 'nn']], 'nn'], [[['charge', 'nn'], ['of', 'in']], 'in'], [[['of', 'in'], ['the', 'at']], 'at'], [[['the', 'at'], ['election', 'nn']], 'nn'], [[['election', 'nn'], [',', ',']], 'in'], [[[',', ','], ['``', '``']], 'cc'], [[['``', '``'], ['deserves', 'vbz']], 'ppss'], [[['deserves', 'vbz'], ['the', 'at']], 'at'], [[['the', 'at'], ['praise', 'nn']], 'nn'], [[['praise', 'nn'], ['and', 'cc']], 'in'], [[['and', 'cc'], ['thanks', 'nns']], 'nn'], [[['thanks', 'nns'], ['of', 'in']], 'in'], [[['of', 'in'], ['the', 'at']], 'at'], [[['the', 'at'], ['City', 'nn-tl']], 'nn'], [[['City', 'nn-tl'], ['of', 'in-tl']], 'nn-tl'], [[['of', 'in-tl'], ['Atlanta', 'np-tl']], 'np-tl'], [[['Atlanta', 'np-tl'], ["''", "''"]], 'nn-tl'], [[["''", "''"], ['for', 'in']], '.'], [[['for', 'in'], ['the', 'at']], 'at'], [[['the', 'at'], ['manner', 'nn']], 'nn'], [[['manner', 'nn'], ['in', 'in']], 'in'], [[['in', 'in'], ['which', 'wdt']], 'at'], [[['which', 'wdt'], ['the', 'at']], 'ppss'], [[['the', 'at'], ['election', 'nn']], 'nn'], [[['election', 'nn'], ['was', 'bedz']], 'in'], [[['was', 'bedz'], ['conducted', 'vbn']], 'vbn'], [[['conducted', 'vbn'], ['.', '.']], 'in'], [[['.', '.'], ['The', 'at']], 'at'], [[['The', 'at'], ['September-October', 'np']], 'nn'], [[['September-October', 'np'], ['term', 'nn']], 'np'], [[['term', 'nn'], ['jury', 'nn']], 'in'], [[['jury', 'nn'], ['had', 'hvd']], 'in'], [[['had', 'hvd'], ['been', 'ben']], 'vbn'], [[['been', 'ben'], ['charged', 'vbn']], 'vbn'], [[['charged', 'vbn'], ['by', 'in']], 'in'], [[['by', 'in'], ['Fulton', 'np-tl']], 'at'], [[['Fulton', 'np-tl'], ['Superior', 'jj-tl']], 'nn-tl'], [[['Superior', 'jj-tl'], ['Court', 'nn-tl']], 'nn-tl'], [[['Court', 'nn-tl'], ['Judge', 'nn-tl']], 'nn-tl'], [[['Judge', 'nn-tl'], ['Durwood', 'np']], 'nn-tl'], [[['Durwood', 'np'], ['Pye', 'np']], 'np'], [[['Pye', 'np'], ['to', 'to']], 'np'], [[['to', 'to'], ['investigate', 'vb']], 'vb'], [[['investigate', 'vb'], ['reports', 'nns']], 'at'], [[['reports', 'nns'], ['of', 'in']], 'in'], [[['of', 'in'], ['possible', 'jj']], 'at'], [[['possible', 'jj'], ['``', '``']], 'n ...

# %%
#confusion matrix for each tagger.

# unigram 
ori_tag = []
pred_tag = []
for i in unigram_tag:
    ori_tag.append(i[0][1])
    pred_tag.append(i[1])

import collections
ori_tag =  collections.Counter(ori_tag)

import collections
pred_tag =  collections.Counter(pred_tag)

ori_tag1 = []
pred_tag1 = []
for value in ori_tag.items() :
    ori_tag1.append(value)
for value in pred_tag.items() :
    pred_tag1.append(value)

conf_matrix = []
d = len(pred_tag1)
for i in ori_tag1:
    for l in range(d):
        if(i[0] == pred_tag1[l][0]):
            temp=[i, pred_tag1[l][1]]
            conf_matrix.append(temp)

temp = []      
for i in conf_matrix:
    temp.append(i[0])
    
for i in ori_tag1:
    if (i not in temp):
        c = [i , 'not in prediction set' ]
        conf_matrix.append(c)
        
#print(conf_matrix)  # conf_matrix = [(tag, orignal tag count),predicted tag count ]

#bigram confusion matrix
bi_ori_tag = []
bi_pred_tag = []
for i in bigram_tag :
    bi_ori_tag.append(i[0][1][1])
    bi_pred_tag.append(i[1])

import collections
bi_ori_tag =  collections.Counter(bi_ori_tag)

import collections
bi_pred_tag =  collections.Counter(bi_pred_tag)

bi_ori_tag1 = []
bi_pred_tag1 = []
for value in bi_ori_tag.items() :
    bi_ori_tag1.append(value)
for value in bi_pred_tag.items() :
    bi_pred_tag1.append(value)

bi_conf_matrix = []
d = len(bi_pred_tag1)
for i in bi_ori_tag1:
    for l in range(d):
        if(i[0] == bi_pred_tag1[l][0]):
            temp=[i, bi_pred_tag1[l][1]]
            bi_conf_matrix.append(temp)

temp = []      
for i in bi_conf_matrix:
    temp.append(i[0])
    
for i in bi_ori_tag1:
    if (i not in temp):
        c = [i , 'not in prediction set' ]
        bi_conf_matrix.append(c)
        
print(bi_conf_matrix)  # conf_matrix = [(tag, orignal tag count),predicted tag count ]
# Out:
# [[('nn', 6517), 9564], [('np-hl', 142), 60], [('fw-nn-tl', 1), 3], [('.-hl', 8), 41], [('nn-hl', 116), 82], [('nn-tl-hl', 8), 9], [(',', 2524), 389], [('.', 2113), 625], [('nns-tl', 200), 48], [('jj-hl', 23), 2], [('nns-tl-hl', 1), 1], [('``', 383), 52], [(',-hl', 49), 2], [('rb', 983), 1], [(':-hl', 2), 21], [('to', 622), 2], [('jj', 1893), 186], [('vb-tl', 2), 1], [('vbg', 715), 13], [('nns', 2415), 1147], [('ppss', 261), 537], [('fw-nns', 1), 1], [('in', 5116), 13733], [('cc', 1248), 2653], [('np', 3927), 3975], [('np-tl', 381), 85], [('at', 4437), 9888], [('pps', 549), 175], [('fw-jj-tl', 1), 1], [('vb-hl', 19), 9], [("''", 363), 33], [('cd-hl', 39), 14], [('in-tl', 85), 2], [('*', 113), 70], [('in-hl', 43), 222], [('at-tl', 22), 1], [('nn-tl', 1299), 2119], [('nns-hl', 63), 9], [('fw-nn', 4), 5], [(')-hl', 11), 142], [('vbn-hl', 42), 2], [('vbn', 1133), 1467], [('bedz', 362), 75], [('vbd', 1352), 755], [('ap-hl', 4), 5], [('vb', 1232), 1671], [('at-hl', 5), 43], [('pps+bez-hl', 1), 'not in prediction set'], [('pps+md', 8), 'not in prediction set'], [('rb-tl', 1), 'not in prediction set'], [('jjr', 54), 'not in prediction set'], [('cd', 1059), 'not in prediction set'], [('be-hl', 1), 'not in prediction set'], [('ben', 113), 'not in prediction set'], [('ppss+hvd', 1), 'not in prediction set'], [('cd-tl', 32), 'not in prediction set'], [('pp$', 530), 'not in prediction set'], [('dt$', 1), 'not in prediction set'], [('beg', 29), 'not in prediction set'], [('cc-tl', 17), 'not in prediction set'], [('ap', 442), 'not in prediction set'], [('hvn', 9), 'not in prediction set'], [('be', 295), 'not in prediction set'], [('od', 175), 'not in prediction set'], [('od-hl', 1), 'not in prediction set'], [('fw-dt', 1), 'not in prediction set'], [('bez-hl', 2), 'not in prediction set'], [('rbr', 39), 'not in prediction set'], [('--', 129), 'not in prediction set'], [('wps', 206), 'not in prediction set'], [('pn', 39), 'not in prediction set'], [(')', 47), 'not in prediction set'], [('ppss+ber', 13), 'not in prediction set'], [('jjs', 25), 'not in prediction set'], [('nps$', 16), 'not in prediction set'], [('ber-hl', 1), 'not in prediction set'], [('nps-hl', 2), 'not in prediction set'], [('ql', 173), 'not in prediction set'], [('2', 2), 'not in prediction set'], [('uh-tl', 1), 'not in prediction set'], [('dod*', 7), 'not in prediction set'], [('md*', 23), 'not in prediction set'], [('vbd-tl', 1), 'not in prediction set'], [('vbg-tl', 11), 'not in prediction set'], [('ex', 75), 'not in prediction set'], [('nps', 108), 'not in prediction set'], [('nn$-hl', 2), 'not in prediction set'], [('dtx', 2), 'not in prediction set'], [('nr$', 12), 'not in prediction set'], [('wpo', 6), 'not in prediction set'], [('dti', 93), 'not in prediction set'], [('wdt', 154), 'not in prediction set'], [('jj-tl', 349), 'not in prediction set'], [('rp-hl', 3), 'not in prediction set'], [('fw-at-tl', 2), 'not in prediction set'], [('rb-hl', 13), 'not in prediction set'], [('uh', 5), 'not in prediction set'], [('doz', 10), 'not in prediction set'], [('np-tl-hl', 1), 'not in prediction set'], [('cs-hl', 1), 'not in prediction set'], [('do*', 8), 'not in prediction set'], [('nr-hl', 2), 'not in prediction set'], [('(-hl', 11), 'not in prediction set'], [('cs', 744), 'not in prediction set'], [('bedz-hl', 1), 'not in prediction set'], [('jjs-tl', 1), 'not in prediction set'], [('do', 25), 'not in prediction set'], [('abn-hl', 1), 'not in prediction set'], [('pp$$', 1), 'not in prediction set'], [('jjr-tl', 2), 'not in prediction set'], [('vbn-tl-hl', 1), 'not in prediction set'], [('pn+hvz', 1), 'not in prediction set'], [('ap$', 1), 'not in prediction set'], [('ppss+md', 24), 'not in prediction set'], [('ppss+bem', 7), 'not in prediction set'], [('bed', 119), 'not in prediction set'], [('vbn-tl', 48), 'not in prediction set'], [('pps+bez', 13), 'not in prediction set'], [('abx', 32), 'not in prediction set'], [('vbz-hl', 35), 'not in prediction set'], [('hv', 126), 'n ...
