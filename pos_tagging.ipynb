# %%
with open('brown.txt','r') as f:
	corpus = f.read() 
	#print(corpus)

# %%
words = corpus.split()        # split function converting whole corpus in to list of words so it will be eassy to handle
#print(words[:])

# %%
N = len(words)
print(N)
# Out:
# 1161192

# %%
brown_test = []
brown_train = []
sen = 0
for i in words:
    if i == './.':
        sen += 1
    if sen < 2000:
        brown_test.append(i)
    else:
        brown_train.append(i)

# %%
f= open("brown_test.txt","w+")
for i in brown_test:
     f.write("%s " %i)    
f.close() 

f= open("brown_train.txt","w+")
for i in brown_train:
     f.write("%s " %i)   
f.close()

# %%
print(len(brown_test))
print(len(brown_train))
# Out:
# 49948
# 1111244

# %%
# getting frequency of tags from brown_train
import collections
types =  collections.Counter(brown_train)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
a = []
for value in types.items() :
    a.append(value)
#print(a)

#sorting array "a" in decending order
def sortthird(a): 
    return a[1] 
a.sort(key = sortthird ,reverse = True) 
#print(a)

#spliting words and tags fron sorted array "a"
b = []
t = 0 
for i in a:
    x = a[t][0]
    j = x.rsplit('/')
    b.append(j)
    t += 1 
# len of b is 64413
    
#cosidering only maximum frequent word-tag pairs from array "b" 
temp =[]
max_fre_word_tag = []
for l in b:
    if (l[0] not in temp):
        temp.append(l[0])
        max_fre_word_tag.append(l)
    
print(max_fre_word_tag)  # now the size of training set come down to 54068 from 1111244 word_tags pairs
# Out:
# [['the', 'at'], [',', ','], ['.', '.'], ['of', 'in'], ['and', 'cc'], ['a', 'at'], ['in', 'in'], ['to', 'to'], ['is', 'bez'], ['was', 'bedz'], ['``', '``'], ["''", "''"], ['for', 'in'], ['with', 'in'], ['he', 'pps'], ['The', 'at'], ['his', 'pp$'], ['that', 'cs'], ['be', 'be'], [';', '.'], ['on', 'in'], ['as', 'cs'], ['I', 'ppss'], ['by', 'in'], ['had', 'hvd'], ['at', 'in'], ['?', '.'], ['not', '*'], ['are', 'ber'], ['from', 'in'], ['or', 'cc'], ['this', 'dt'], ['have', 'hv'], ['it', 'pps'], ['which', 'wdt'], ['an', 'at'], ['--', '--'], ['were', 'bed'], ['He', 'pps'], ['but', 'cc'], ['they', 'ppss'], ['him', 'ppo'], ['would', 'md'], ['all', 'abn'], ['their', 'pp$'], ['been', 'ben'], ['one', 'cd'], ['has', 'hvz'], [')', ')'], ['(', '('], ['who', 'wps'], ['It', 'pps'], ['she', 'pps'], ['we', 'ppss'], ['will', 'md'], ['you', 'ppss'], ['them', 'ppo'], ['her', 'pp$'], ['into', 'in'], ['In', 'in'], ['its', 'pp$'], ['can', 'md'], ['when', 'wrb'], ['up', 'rp'], ['!', '.'], ['other', 'ap'], ['out', 'rp'], ['could', 'md'], ['no', 'at'], ['time', 'nn'], [':', ':'], ['said', 'vbd'], ['if', 'cs'], ['what', 'wdt'], ['some', 'dti'], ['But', 'cc'], ['there', 'ex'], ['may', 'md'], ['than', 'cs'], ['any', 'dti'], ['only', 'rb'], ['do', 'do'], ['two', 'cd'], ['these', 'dts'], ['about', 'in'], ['me', 'ppo'], ['my', 'pp$'], ['This', 'dt'], ['our', 'pp$'], ['man', 'nn'], ['A', 'at'], ['now', 'rb'], ['Af', 'nn'], ['then', 'rb'], ['more', 'ql'], ['new', 'jj'], ['must', 'md'], ['did', 'dod'], ['like', 'cs'], ['also', 'rb'], ['She', 'pps'], ['years', 'nns'], ['so', 'ql'], ['such', 'jj'], ['many', 'ap'], ['first', 'od'], ['way', 'nn'], ['your', 'pp$'], ['through', 'in'], ['And', 'cc'], ['They', 'ppss'], ['should', 'md'], ['where', 'wrb'], ['even', 'rb'], ['There', 'ex'], ['people', 'nns'], ['over', 'in'], ['those', 'dts'], ['make', 'vb'], ['own', 'jj'], ['each', 'dt'], ['Mr.', 'np'], ['If', 'cs'], ['see', 'vb'], ['men', 'nns'], ['between', 'in'], ['back', 'rb'], ['get', 'vb'], ['good', 'jj'], ['down', 'rp'], ['life', 'nn'], ['same', 'ap'], ['still', 'rb'], ['very', 'ql'], ['world', 'nn'], ['us', 'ppo'], ['We', 'ppss'], ['know', 'vb'], ['just', 'rb'], ['because', 'cs'], ['never', 'rb'], ['might', 'md'], ['being', 'beg'], ['well', 'rb'], ['made', 'vbn'], ['most', 'ql'], ['both', 'abx'], ['came', 'vbd'], ['under', 'in'], ['day', 'nn'], ['himself', 'ppl'], ['great', 'jj'], ['go', 'vb'], ['few', 'ap'], ['year', 'nn'], ['against', 'in'], ['When', 'wrb'], ['old', 'jj'], ['here', 'rb'], ['work', 'nn'], ['another', 'dt'], ['take', 'vb'], ['again', 'rb'], ['without', 'in'], ['You', 'ppss'], ['His', 'pp$'], ['too', 'ql'], ['long', 'jj'], ['small', 'jj'], ['New', 'jj-tl'], ['three', 'cd'], ['after', 'in'], ['last', 'ap'], ['went', 'vbd'], ['how', 'wrb'], ['For', 'in'], ['used', 'vbn'], ['place', 'nn'], ['say', 'vb'], ['state', 'nn'], ['As', 'cs'], ['while', 'cs'], ['course', 'nn'], ['off', 'rp'], ['much', 'ap'], ['part', 'nn'], ['number', 'nn'], ['away', 'rb'], ['always', 'rb'], ['fact', 'nn'], ['What', 'wdt'], ['every', 'at'], ['upon', 'in'], ['does', 'doz'], ['during', 'in'], ['United', 'vbn-tl'], ['think', 'vb'], ['something', 'pn'], ['water', 'nn'], ['took', 'vbd'], ['States', 'nns-tl'], ['American', 'jj'], ['hand', 'nn'], ['high', 'jj'], ['head', 'nn'], ['At', 'in'], ['eyes', 'nns'], ['knew', 'vbd'], ["didn't", 'dod*'], ['find', 'vb'], ['little', 'ap'], ['before', 'cs'], ['system', 'nn'], ["don't", 'do*'], ['come', 'vb'], ['going', 'vbg'], ['school', 'nn'], ['house', 'nn'], ['toward', 'in'], ['group', 'nn'], ['important', 'jj'], ['room', 'nn'], ['possible', 'jj'], ['give', 'vb'], ['nothing', 'pn'], ['once', 'rb'], ['things', 'nns'], ['days', 'nns'], ['side', 'nn'], ['given', 'vbn'], ['end', 'nn'], ['night', 'nn'], ['often', 'rb'], ['social', 'jj'], ['use', 'nn'], ['point', 'nn'], ['business', 'nn'], ['young', 'jj'], ['though', 'cs'], ['These', 'dts'], ['large', 'jj'], ['per', 'in'], ['case', 'nn'], ['order', 'nn'], ['thought', 'vbd'], ['saw', 'vbd'], ['Then', 'r ...

# %%
# word_tags pair from brown_test corpus
# getting frequency of tags from brown_test
import collections
types =  collections.Counter(brown_test)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
s = []
for value in types.items() :
    s.append(value)
#print(a)

#sorting array "a" in decending order
def sortthird(s): 
    return s[1] 
s.sort(key = sortthird ,reverse = True) 
#print(a)

#spliting words and tags fron sorted array "a"
test_words = []
t = 0 
for i in s:
    x = s[t][0]
    j = x.rsplit('/')
    test_words.append(j)
    t += 1 
# len of test_words1 is 10061    
print(test_words)  # now the size of test set come down to 10061 from 49948 word_tags pairs
# Out:
# [['the', 'at'], [',', ','], ['.', '.'], ['of', 'in'], ['and', 'cc'], ['a', 'at'], ['in', 'in'], ['to', 'to'], ['for', 'in'], ['to', 'in'], ['The', 'at'], ['``', '``'], ["''", "''"], ['was', 'bedz'], ['is', 'bez'], ['on', 'in'], ['be', 'be'], ['at', 'in'], ['said', 'vbd'], ['that', 'cs'], ['by', 'in'], ['will', 'md'], ['he', 'pps'], ['with', 'in'], ['his', 'pp$'], ['Mrs.', 'np'], ['as', 'cs'], ['would', 'md'], ['has', 'hvz'], ['who', 'wps'], ['an', 'at'], ['from', 'in'], ['are', 'ber'], ['--', '--'], ['have', 'hv'], ['were', 'bed'], ['He', 'pps'], ['been', 'ben'], ['this', 'dt'], ['not', '*'], ['Mr.', 'np'], ['which', 'wdt'], ['had', 'hvd'], ['their', 'pp$'], ['it', 'pps'], ['two', 'cd'], ['one', 'cd'], ['last', 'ap'], ['they', 'ppss'], ['I', 'ppss'], ['but', 'cc'], ['its', 'pp$'], ['or', 'cc'], ['year', 'nn'], ['of', 'in-tl'], ['when', 'wrb'], ['first', 'od'], [';', '.'], ['out', 'rp'], ['also', 'rb'], ['other', 'ap'], ['new', 'jj'], ['A', 'at'], ['It', 'pps'], ['it', 'ppo'], ['up', 'rp'], ['more', 'ap'], ['all', 'abn'], ['state', 'nn'], ['years', 'nns'], ['into', 'in'], ['In', 'in'], ['over', 'in'], ['three', 'cd'], ['no', 'at'], [':', ':'], ['there', 'ex'], ['some', 'dti'], ['that', 'wps'], ['night', 'nn'], ['that', 'dt'], ['her', 'pp$'], ['against', 'in'], [',', ',-hl'], ['(', '('], ['administration', 'nn'], [')', ')'], ['him', 'ppo'], ['New', 'jj-tl'], ['game', 'nn'], ['now', 'rb'], ['But', 'cc'], ['city', 'nn'], ['after', 'in'], ['State', 'nn-tl'], ['can', 'md'], ['Monday', 'nr'], ['after', 'cs'], ['them', 'ppo'], ['should', 'md'], ['home', 'nn'], ['could', 'md'], ['United', 'vbn-tl'], ['time', 'nn'], ['here', 'rb'], ['what', 'wdt'], ['if', 'cs'], ['Jr.', 'np'], ['program', 'nn'], ['bill', 'nn'], ['we', 'ppss'], ['under', 'in'], ['today', 'nr'], ['did', 'dod'], ['John', 'np'], ['home', 'nr'], ['Miss', 'np'], ['President', 'nn-tl'], ['during', 'in'], ['four', 'cd'], ['House', 'nn-tl'], ['man', 'nn'], ['back', 'rb'], ['election', 'nn'], ['members', 'nns'], ['per', 'in'], ['school', 'nn'], ['Sunday', 'nr'], ['yesterday', 'nr'], ['week', 'nn'], ['This', 'dt'], ['government', 'nn'], ['made', 'vbn'], ["'", "'"], ['plan', 'nn'], ['where', 'wrb'], ['day', 'nn'], ['States', 'nns-tl'], ['tax', 'nn'], ['get', 'vb'], ['only', 'ap'], ['committee', 'nn'], ['than', 'in'], ['as', 'ql'], ['City', 'nn-tl'], ['Democratic', 'jj-tl'], ['James', 'np'], ['season', 'nn'], ['about', 'in'], ['jury', 'nn'], ['any', 'dti'], ['A.', 'np'], ['J.', 'np'], ['million', 'cd'], ['people', 'nns'], ['Friday', 'nr'], ['board', 'nn'], ['being', 'beg'], ['Tuesday', 'nr'], ['than', 'cs'], ['before', 'in'], ['take', 'vb'], ['party', 'nn'], ['ball', 'nn'], ['1', 'cd'], ['made', 'vbd'], ['president', 'nn'], ['chairman', 'nn'], ['team', 'nn'], ['University', 'nn-tl'], ['?', '.'], ['both', 'abx'], ['meeting', 'nn'], ['federal', 'jj'], ['Dr.', 'nn-tl'], ['cent', 'nn'], ['do', 'do'], ['several', 'ap'], ['each', 'dt'], ['days', 'nns'], ['expected', 'vbn'], ['make', 'vb'], ['C.', 'np'], ['told', 'vbd'], ['must', 'md'], ['schools', 'nns'], ['They', 'ppss'], ['W.', 'np'], ['another', 'dt'], ['off', 'rp'], ['such', 'jj'], ['about', 'rb'], ['Saturday', 'nr'], ['County', 'nn-tl'], ['children', 'nns'], ['five', 'cd'], ['then', 'rb'], ['session', 'nn'], ['third', 'od'], ['next', 'ap'], ['club', 'nn'], ['go', 'vb'], ['between', 'in'], ['without', 'in'], ['only', 'rb'], ['in', 'rp'], ['special', 'jj'], ['There', 'ex'], ['down', 'rp'], ['B.', 'np'], ['York', 'np-tl'], ['former', 'ap'], ['10', 'cd'], ['His', 'pp$'], ['E.', 'np'], ['our', 'pp$'], ['Laos', 'np'], ['given', 'vbn'], ['Hughes', 'np'], ['local', 'jj'], ['those', 'dts'], ['L.', 'np'], ['most', 'ql'], ['may', 'md'], ['law', 'nn'], ['work', 'nn'], ['through', 'in'], ['these', 'dts'], ['men', 'nns'], ['William', 'np'], ['D.', 'np'], ['daughter', 'nn'], ['director', 'nn'], ['play', 'vb'], ['just', 'rb'], ['Texas', 'np'], ['Committee', 'nn-tl'], ['came', 'vbd'], ['record', 'nn'], ['give', 'vb'], ['National', 'jj-tl'], ['taken', ...

# %%
#maximum occuring tag in training corpus
mt = []
for i in max_fre_word_tag:
    mt.append(i[1])

import collections
mmt =  collections.Counter(mt)
print(mmt)  # list of maxximum occuring tag
# Out:
# Counter({'nn': 12405, 'jj': 7398, 'nns': 6810, 'np': 6310, 'vbg': 2701, 'vbn': 2573, 'vb': 1888, 'rb': 1805, 'nn-tl': 1687, 'vbd': 1338, 'cd': 1263, 'np$': 1135, 'vbz': 908, 'np-tl': 669, 'nns-tl': 500, 'nn$': 463, 'jj-tl': 378, 'nps': 367, 'nn-hl': 186, 'fw-nn': 169, 'jjt': 157, 'jjr': 147, 'ql': 144, 'in': 138, 'uh': 137, 'nn$-tl': 132, 'nns$': 118, 'fw-nn-tl': 104, 'cd-tl': 96, 'od': 88, 'nns-hl': 82, 'jj-hl': 70, 'fw-nns': 58, 'np$-tl': 56, 'fw-jj-tl': 52, 'vbg-tl': 52, 'cs': 50, 'fw-jj': 42, 'vbg-hl': 42, 'nns$-tl': 35, 'vbn-tl': 35, 'od-tl': 34, 'pn': 33, 'ap': 33, 'np-hl': 32, 'vb-tl': 32, 'md': 30, 'nr': 29, 'fw-nns-tl': 26, 'wrb': 25, 'pp$': 24, 'fw-vb': 22, 'fw-rb': 21, 'nps-tl': 21, 'nil': 20, 'nps$': 20, 'ppss': 20, 'nn+bez': 18, 'rbr': 17, 'cc': 17, 'ppo': 16, 'cd-hl': 16, 'md*': 15, 'ppss+md': 13, 'vbz-tl': 13, 'np+bez': 12, 'at': 12, 'fw-at+nn-tl': 12, 'fw-in-tl': 11, 'ppl': 11, 'nn-nc': 11, '2': 11, 'pn$': 10, 'vbn-hl': 9, 'vbz-hl': 9, 'wdt': 9, 'nr$': 9, 'pps+md': 9, 'pp$$': 9, 'nn-tl-hl': 8, 'fw-in': 8, 'jjs': 8, 'ppss+ber': 8, 'dt': 8, 'fw-at': 7, 'pps': 7, 'wps': 7, 'fw-nn$': 7, 'fw-at-tl': 7, 'dti': 7, 'fw-uh': 7, 'fw-np': 7, 'ppss+hv': 7, 'dts': 7, 'uh-tl': 7, 'pps+bez': 7, 'rp': 7, 'fw-vbg': 7, 'fw-cc': 6, 'pn+bez': 6, 'rb-tl': 6, 'bez*': 5, 'beg': 5, 'md+hv': 5, 'fw-nn-nc': 5, 'abn': 5, 'fw-wdt': 5, 'nrs': 5, 'fw-ppss': 5, 'vb+ppo': 4, 'fw-in+nn': 4, 'vb-hl': 4, 'fw-vbz': 4, 'fw-*': 4, '.': 4, 'wps+md': 4, 'fw-vbn': 4, 'ppls': 4, '*': 4, 'fw-np-tl': 4, 'np+hvz': 4, 'vbd-tl': 4, 'nn+hvz': 4, 'hv': 4, 'do': 4, 'jjt-tl': 3, 'wp$': 3, 'hvz': 3, 'nn$-hl': 3, 'hvg': 3, 'in-tl': 3, 'pn+md': 3, 'ex': 3, 'fw-vb-nc': 3, 'dod*': 3, 'fw-ber': 3, 'nr-tl': 3, 'do*': 3, 'bez': 3, 'fw-nr-tl': 3, 'jjr-hl': 3, '8': 3, 'fw-cd': 3, 'wrb+dod': 3, 'fw-pp$': 3, 'nns$-hl': 3, 'bed': 3, 'fw-ppo': 3, 'fw-in+at': 3, 'fw-in+at-tl': 3, 'mbf': 3, 'to': 3, 'dt+bez': 3, '': 2, 'vb-nc': 2, 'hv*': 2, 'nn+md': 2, 'vb+to': 2, 'bem': 2, 'np$-hl': 2, 'rb-nc': 2, 'rbt': 2, 'uh-nc': 2, 'ber': 2, 'bedz': 2, 'fw-cs': 2, 'dod': 2, 'nps-hl': 2, 'np+md': 2, 'fw-jj-nc': 2, 'be': 2, 'np-nc': 2, 'rb-hl': 2, 'fw-bez': 2, 'fw-rb-tl': 2, 'abx': 2, 'dtx': 2, 'fw-ppl': 2, 'rb+bez': 2, 'jjs-tl': 2, 'nr$-tl': 2, 'jjr-tl': 2, 'fw-in+np-tl': 2, "4''": 2, 'ex+hvd': 2, 'fw-ppl+vbz': 2, 'hvd*': 2, 'nns+md': 2, 'wdt+bez': 2, 'ber*': 2, 'fw-pp$-tl': 2, 'jj+jj-nc': 2, 'm.': 2, 'vb+in': 2, 'wpo': 2, 'bed*': 2, 'rp+in': 2, '(': 2, 'fw-at+np-tl': 2, 'fw-vbd': 2, 'bedz*': 2, 'ex+bez': 2, 'nps$-tl': 2, 'to+vb': 2, 'fw-ppo+in': 2, 'fw-nn$-tl': 2, 'fw-nps': 2, 'doz*': 2, 'rb+cs': 2, 'ex+md': 2, 'wps+bez': 2, 'ppss+bem': 2, 'fw-od-tl': 2, ',': 2, 'vbg+to': 2, 'fw-nns-nc': 2, 'doz': 2, 'vbz-nc': 2, 'hvd': 2, 'fw-cd-tl': 2, 'jj-tl-hl': 2, 'fw-in+nn-tl': 2, '2-inch': 2, 'pps+hvd': 2, 'fw-vbg-tl': 1, 'fw-pn': 1, 'uh-hl': 1, 'vb+rp': 1, 'wrb+dod*': 1, 'nn+nn-nc': 1, 'ben-tl': 1, 'wrb+bez-tl': 1, 'ppo-tl': 1, 'jj$-tl': 1, '2-foot': 1, 'vbg-nc': 1, 'wdt+ber': 1, 'fw-ppss+hv': 1, 'ben': 1, 'nn+hvd-tl': 1, 'nn+bez-tl': 1, 'jjr+cs': 1, 'wrb+ber': 1, 'vbn-nc': 1, 'at-tl': 1, 'fw-wps': 1, 'vb+jj-nc': 1, 'fw-nr': 1, 'l': 1, '29': 1, 'ppss+vb': 1, 'vb+at': 1, 'fw-od-nc': 1, 'pn+hvd': 1, 'cell': 1, 'ap+ap-nc': 1, '7074': 1, 'fw-rb+cc': 1, 'fw-in+at-t': 1, 'ft': 1, 'fw-pps': 1, 'wdt+do+pps': 1, 'fw-vb-tl': 1, 'ap$': 1, '--': 1, ')': 1, '3%': 1, "'": 1, 'in+ppo': 1, 'md+to': 1, 'nns-nc': 1, 'ppl-tl': 1, 'nps-nc': 1, 'nns$-nc': 1, 'nn+in': 1, 'rb$': 1, 'ppss+bez*': 1, 'fw-cc-tl': 1, 'ppss+bez': 1, 'wrb+do': 1, 'fw-dt+bez': 1, 'fw-nps-tl': 1, 'dt$': 1, 'qlp': 1, 'vb+vb-nc': 1, 'fw-hv': 1, 'dt+md': 1, 'wdt+ber+pp': 1, 'rbr+cs': 1, 'jjt-nc': 1, 'hv+to': 1, 'wrb+in': 1, 'rn': 1, '3': 1, 'hvn': 1, 'fw-wpo': 1, 'dts+bez': 1, 'wdt+dod': 1, 'md+ppss': 1, 'fw-to+vb': 1, 'vbn+to': 1, 'fw-vbd-tl': 1, 'sec': 1, 'ppss+hvd': 1, ':': 1, '``': 1, 'sq.': 1, 'cd$': 1, 'nps$-hl': 1, 'fw-dts': 1, 'nrs-tl': 1, 'np+bez-nc': 1, 'hp': 1, 'in+in': 1, 'fw-uh-nc': 1, 'hvz*': 1, 'Output': 1, 'jjt-hl': 1, 'cc-tl': 1, ' ...

# %%
#unigram tagger for each unique words from training corpus

unigram_tag = []
y = len(max_fre_word_tag)
for i in test_words:
    for l in range(y): 
        if (i[0] == max_fre_word_tag[l][0]):
            temp = [i , max_fre_word_tag[l][1]]
            unigram_tag.append(temp)
            break;
#unigram_tag
temp = []
for i in unigram_tag:
    temp.append(i[0])

for i in test_words:
    if(i not in temp):
        temp1 = [i , 'unk']
        unigram_tag.append(temp1)
        
print(unigram_tag) # unknown words are tagged as 'unk' tag at the bottom of list 

# we can tag unknown words by taking maximum occurring tag in this case it is "nn" have frequency 12403

f= open("unigram_tag_pred.txt","w+")
for i in unigram_tag:
     f.write("%s " %i)
    
f.close()
# Out:
# [[['the', 'at'], 'at'], [[',', ','], ','], [['.', '.'], '.'], [['of', 'in'], 'in'], [['and', 'cc'], 'cc'], [['a', 'at'], 'at'], [['in', 'in'], 'in'], [['to', 'to'], 'to'], [['for', 'in'], 'in'], [['to', 'in'], 'to'], [['The', 'at'], 'at'], [['``', '``'], '``'], [["''", "''"], "''"], [['was', 'bedz'], 'bedz'], [['is', 'bez'], 'bez'], [['on', 'in'], 'in'], [['be', 'be'], 'be'], [['at', 'in'], 'in'], [['said', 'vbd'], 'vbd'], [['that', 'cs'], 'cs'], [['by', 'in'], 'in'], [['will', 'md'], 'md'], [['he', 'pps'], 'pps'], [['with', 'in'], 'in'], [['his', 'pp$'], 'pp$'], [['Mrs.', 'np'], 'np'], [['as', 'cs'], 'cs'], [['would', 'md'], 'md'], [['has', 'hvz'], 'hvz'], [['who', 'wps'], 'wps'], [['an', 'at'], 'at'], [['from', 'in'], 'in'], [['are', 'ber'], 'ber'], [['--', '--'], '--'], [['have', 'hv'], 'hv'], [['were', 'bed'], 'bed'], [['He', 'pps'], 'pps'], [['been', 'ben'], 'ben'], [['this', 'dt'], 'dt'], [['not', '*'], '*'], [['Mr.', 'np'], 'np'], [['which', 'wdt'], 'wdt'], [['had', 'hvd'], 'hvd'], [['their', 'pp$'], 'pp$'], [['it', 'pps'], 'pps'], [['two', 'cd'], 'cd'], [['one', 'cd'], 'cd'], [['last', 'ap'], 'ap'], [['they', 'ppss'], 'ppss'], [['I', 'ppss'], 'ppss'], [['but', 'cc'], 'cc'], [['its', 'pp$'], 'pp$'], [['or', 'cc'], 'cc'], [['year', 'nn'], 'nn'], [['of', 'in-tl'], 'in'], [['when', 'wrb'], 'wrb'], [['first', 'od'], 'od'], [[';', '.'], '.'], [['out', 'rp'], 'rp'], [['also', 'rb'], 'rb'], [['other', 'ap'], 'ap'], [['new', 'jj'], 'jj'], [['A', 'at'], 'at'], [['It', 'pps'], 'pps'], [['it', 'ppo'], 'pps'], [['up', 'rp'], 'rp'], [['more', 'ap'], 'ql'], [['all', 'abn'], 'abn'], [['state', 'nn'], 'nn'], [['years', 'nns'], 'nns'], [['into', 'in'], 'in'], [['In', 'in'], 'in'], [['over', 'in'], 'in'], [['three', 'cd'], 'cd'], [['no', 'at'], 'at'], [[':', ':'], ':'], [['there', 'ex'], 'ex'], [['some', 'dti'], 'dti'], [['that', 'wps'], 'cs'], [['night', 'nn'], 'nn'], [['that', 'dt'], 'cs'], [['her', 'pp$'], 'pp$'], [['against', 'in'], 'in'], [[',', ',-hl'], ','], [['(', '('], '('], [['administration', 'nn'], 'nn'], [[')', ')'], ')'], [['him', 'ppo'], 'ppo'], [['New', 'jj-tl'], 'jj-tl'], [['game', 'nn'], 'nn'], [['now', 'rb'], 'rb'], [['But', 'cc'], 'cc'], [['city', 'nn'], 'nn'], [['after', 'in'], 'in'], [['State', 'nn-tl'], 'nn-tl'], [['can', 'md'], 'md'], [['Monday', 'nr'], 'nr'], [['after', 'cs'], 'in'], [['them', 'ppo'], 'ppo'], [['should', 'md'], 'md'], [['home', 'nn'], 'nr'], [['could', 'md'], 'md'], [['United', 'vbn-tl'], 'vbn-tl'], [['time', 'nn'], 'nn'], [['here', 'rb'], 'rb'], [['what', 'wdt'], 'wdt'], [['if', 'cs'], 'cs'], [['Jr.', 'np'], 'np'], [['program', 'nn'], 'nn'], [['bill', 'nn'], 'nn'], [['we', 'ppss'], 'ppss'], [['under', 'in'], 'in'], [['today', 'nr'], 'nr'], [['did', 'dod'], 'dod'], [['John', 'np'], 'np'], [['home', 'nr'], 'nr'], [['Miss', 'np'], 'np'], [['President', 'nn-tl'], 'nn-tl'], [['during', 'in'], 'in'], [['four', 'cd'], 'cd'], [['House', 'nn-tl'], 'nn-tl'], [['man', 'nn'], 'nn'], [['back', 'rb'], 'rb'], [['election', 'nn'], 'nn'], [['members', 'nns'], 'nns'], [['per', 'in'], 'in'], [['school', 'nn'], 'nn'], [['Sunday', 'nr'], 'nr'], [['yesterday', 'nr'], 'nr'], [['week', 'nn'], 'nn'], [['This', 'dt'], 'dt'], [['government', 'nn'], 'nn'], [['made', 'vbn'], 'vbn'], [["'", "'"], "'"], [['plan', 'nn'], 'nn'], [['where', 'wrb'], 'wrb'], [['day', 'nn'], 'nn'], [['States', 'nns-tl'], 'nns-tl'], [['tax', 'nn'], 'nn'], [['get', 'vb'], 'vb'], [['only', 'ap'], 'rb'], [['committee', 'nn'], 'nn'], [['than', 'in'], 'cs'], [['as', 'ql'], 'cs'], [['City', 'nn-tl'], 'nn-tl'], [['Democratic', 'jj-tl'], 'jj-tl'], [['James', 'np'], 'np'], [['season', 'nn'], 'nn'], [['about', 'in'], 'in'], [['jury', 'nn'], 'nn'], [['any', 'dti'], 'dti'], [['A.', 'np'], 'np'], [['J.', 'np'], 'np'], [['million', 'cd'], 'cd'], [['people', 'nns'], 'nns'], [['Friday', 'nr'], 'nr'], [['board', 'nn'], 'nn'], [['being', 'beg'], 'beg'], [['Tuesday', 'nr'], 'nr'], [['than', 'cs'], 'cs'], [['before', 'in'], 'cs'], [['take', 'vb'], 'vb'], [['party', 'nn ...

# %%
# seprating tags and words from brown _test
q = []
for i in brown_test:
    j = i.rsplit('/')
    q.append(j)

# %%
z = len(unigram_tag)
seq_unigram_tag = []
for i in q:
    for j in range(z):
        if (i[0] == unigram_tag[j][0][0]):
            temp = [i, unigram_tag[j][1]]
            seq_unigram_tag.append(temp)
            break;

# %%
f= open("brown_test_unigram_pred.txt","w+")
for i in seq_unigram_tag:
     f.write("%s " %i)
    
f.close()

# %%
# unigram pos accuracy
temp = 0
for i in seq_unigram_tag:
    if (i[0][1]==i[1]):
        temp += 1
d = len(seq_unigram_tag)
pos_accuracy = (temp/d)*100

print(pos_accuracy)
# Out:
# 86.0815247857772

# %%
# bigram tagging model of brown_train corpus
# seprating tags and words and counting each word tag pair for brown _train
q = []
for i in brown_train:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_train = [[]for i in range(x)]
for i in range(x):
    if i+1 < x:   
        bigram_train[i].append( q[i] )   
        bigram_train[i].append( q[i+1])
    
#print (bigram_train)   #bigram_train list have 1111244 

x = len(bigram_train)
bigram_tag = []
for i in range(x-1):
    p =[bigram_train[i][0][1] , bigram_train[i][1][1]]
    bigram_tag.append(p)
    
    
# getting frequency of tags from brown_train
from collections import Counter
types =  Counter(tuple(x) for x in bigram_tag)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
s = []
for value in types.items() :
    s.append(value)
#print(s)

#sorting array "a" in decending order
def sortthird(s): 
    return s[1] 
s.sort(key = sortthird ,reverse = True) 
#print(s)            # bigram_training corpus get reduced from 1111244 to 455628 pairs

q = [] 
for i in s:
    q.append(i[0])

temp =[]
bi_max_fre_word_tag = []
for l in q:
    if (l[0] not in temp):
        temp.append(l[0])
        bi_max_fre_word_tag.append(l)
    
#print(bi_max_fre_word_tag)  # now the size of training set come down to 519 from 1111244 word_tags pairs

f= open("bi_max_fre_word_tag.txt","w+")
for i in bi_max_fre_word_tag:
     f.write(str(i))
     f.write("\n")
f.close()

# %%
# forming bigram model as list from test corpus
# seprating tags and words and counting each word tag pair for brown _test
q = []
for i in brown_test:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_test = [[]for i in range(x)]
for i in range(x):
    if i+1 < x:   
        bigram_test[i].append( q[i] )   
        bigram_test[i].append( q[i+1])
    
#print (bigram_test)   #bigram_test list have 49948

f= open("bigram_test.txt","w+")
for i in bigram_test:
     f.write(str(i))
     f.write("\n")
f.close()

# %%
#bigram tagger  predictions for test set from training corpus

bigram_tag_pre = []
x = len(bigram_test)
y = len(bi_max_fre_word_tag)
for i in range(x-1):
    g = bigram_test[i][0][1]
    for l in range(y): 
        if (g == bi_max_fre_word_tag[l][0]):
            temp = [bigram_test[i] , bi_max_fre_word_tag[l][1]]
            bigram_tag_pre.append(temp)
            break;

#print(bigram_tag)  # bigram_tag = [[[word,tag],[word,tag]], predicted tag]
# here we are considering only previous tag for bigram so unknown word will get tagged based there previous tag by MLE of tags 

f= open("bigram_tag_predicted.txt","w+")
for i in bigram_tag_pre:
     f.write(str(i))
     f.write("\n")
f.close()

# %%
#bigram pos accuray
temp = 0
for i in bigram_tag_pre:
    if (i[0][1][1]==i[1]):
        temp += 1
d = len(bigram_tag_pre)
pos_accuracy = (temp/d)*100

print(pos_accuracy)
# Out:
# 31.836930839774137

# %%
# confusion matrix for unigram
temp = [] 
for i in seq_unigram_tag:
    w =[i[0][1] , i[1]]
    temp.append(w)

conf_matrix = []
from collections import Counter
conf_matrix =  Counter(tuple(x) for x in temp)
print(conf_matrix)
# Out:
# Counter({('nn', 'nn'): 5709, ('in', 'in'): 4552, ('at', 'at'): 4438, ('np', 'np'): 2708, (',', ','): 2524, ('nns', 'nns'): 2144, ('.', '.'): 2113, ('jj', 'jj'): 1630, ('cc', 'cc'): 1243, ('nn-tl', 'nn-tl'): 1151, ('np', 'unk'): 1058, ('vb', 'vb'): 935, ('cd', 'cd'): 927, ('vbd', 'vbd'): 918, ('vbn', 'vbn'): 842, ('rb', 'rb'): 820, ('cs', 'cs'): 674, ('to', 'to'): 622, ('vbg', 'vbg'): 621, ('md', 'md'): 600, ('pps', 'pps'): 549, ('pp$', 'pp$'): 529, ('in', 'to'): 419, ('vbd', 'vbn'): 386, ('``', '``'): 383, ("''", "''"): 363, ('bedz', 'bedz'): 362, ('nr', 'nr'): 331, ('bez', 'bez'): 328, ('ap', 'ap'): 327, ('nn', 'unk'): 310, ('be', 'be'): 295, ('ppss', 'ppss'): 261, ('jj-tl', 'jj-tl'): 259, ('vbn', 'vbd'): 246, ('vb', 'nn'): 234, ('dt', 'dt'): 214, ('np-tl', 'np'): 203, ('nns', 'unk'): 182, ('rp', 'rp'): 177, ('nn', 'vb'): 175, ('od', 'od'): 167, ('jj', 'unk'): 165, ('hvz', 'hvz'): 165, ('vbz', 'vbz'): 157, ('wps', 'wps'): 155, ('wdt', 'wdt'): 154, ('wrb', 'wrb'): 146, ('ber', 'ber'): 133, ('--', '--'): 129, ('nn', 'jj'): 128, ('nns-tl', 'nns-tl'): 128, ('hv', 'hv'): 126, ('bed', 'bed'): 119, ('*', '*'): 113, ('ben', 'ben'): 113, ('cd', 'unk'): 112, ('ppo', 'ppo'): 111, ('np$', 'unk'): 106, ('hvd', 'hvd'): 100, ('np-hl', 'np'): 100, ('nn-tl', 'unk'): 97, ('dti', 'dti'): 93, ('in', 'cs'): 86, ('in-tl', 'in'): 84, ('np-tl', 'unk'): 83, ('np-tl', 'np-tl'): 83, ('nn$', 'nn$'): 83, ('ql', 'ql'): 80, ('ex', 'ex'): 75, ('ap', 'ql'): 73, ('abn', 'abn'): 72, ('nn-hl', 'nn'): 66, ('nps', 'nps'): 65, ('np', 'np-tl'): 65, ('ppo', 'pps'): 62, ('nns', 'vbz'): 61, ('vbg', 'unk'): 60, ('nns-tl', 'unk'): 56, ('cs', 'in'): 55, ('nn', 'vbg'): 53, ('dts', 'dts'): 52, (':', ':'): 52, ('wps', 'cs'): 51, ('rp', 'in'): 51, ('dt', 'cs'): 50, (',-hl', ','): 49, ('(', '('): 48, ('vbz', 'nns'): 48, (')', ')'): 47, ('rb', 'jj'): 47, ('np$', 'np$'): 46, ('vbn-tl', 'vbn-tl'): 45, ('rb', 'in'): 45, ('np', 'nn-tl'): 44, ('jj-tl', 'jj'): 43, ('nns-hl', 'nns'): 43, ('jjt', 'jjt'): 43, ('jjr', 'jjr'): 42, ('nps', 'unk'): 41, ('in', 'rp'): 40, ('nn', 'nr'): 40, ('in-hl', 'in'): 38, ('cd-hl', 'cd'): 37, ('pn', 'pn'): 36, ('jj', 'nn'): 36, ('nn', 'nn-tl'): 35, ('dod', 'dod'): 35, ('ql', 'cs'): 34, ('abx', 'abx'): 32, ('nn$', 'unk'): 32, ("'", "'"): 31, ('vbn-hl', 'vbn'): 31, ('ap', 'rb'): 30, ('vbd', 'unk'): 29, ('beg', 'beg'): 29, ('ql', 'rb'): 29, ('vbg', 'nn'): 28, ('rbr', 'rbr'): 25, ('do', 'do'): 25, ('vbn', 'unk'): 25, ('np-hl', 'unk'): 24, ('md*', 'md*'): 23, ('nn-tl', 'nn'): 23, ('ppss+md', 'ppss+md'): 23, ('jj', 'rb'): 22, ('vb', 'unk'): 22, ('at-tl', 'at'): 22, ('nn-hl', 'unk'): 21, ('vbz-hl', 'unk'): 20, ('wrb', 'rb'): 20, ('cd-tl', 'unk'): 19, ('nn$-tl', 'nn$-tl'): 19, ('jj-tl', 'unk'): 19, ('nns', 'nn'): 18, ('rb', 'ql'): 17, ('np', 'np-hl'): 17, ('vbn', 'vb'): 17, ('cd', 'cd-tl'): 16, ('vbz', 'unk'): 16, ('jj-hl', 'jj'): 15, ('nps$', 'unk'): 15, ('vbd', 'vb'): 15, ('nns-hl', 'unk'): 15, ('jjs', 'nn'): 15, ('rb', 'ex'): 14, ('cc-tl', 'cc'): 14, ('vb-hl', 'vb'): 13, ('cd-tl', 'cd'): 13, ('nn-hl', 'nn-tl'): 13, ('pps+bez', 'pps+bez'): 13, ('ppl', 'ppl'): 13, ('ql', 'ap'): 13, ('ppss+ber', 'ppss+ber'): 13, ('jj-tl', 'nn-tl'): 13, ('rb', 'cs'): 13, ('rb', 'unk'): 12, ('rbr', 'jjr'): 12, ('vb', 'jj'): 12, ('np', 'jj-tl'): 12, ('ppo', 'pp$'): 11, (')-hl', ')'): 11, ('nns-tl', 'nns'): 11, ('abl', 'jj'): 11, ('ppls', 'ppls'): 11, ('(-hl', '('): 11, ('cs', 'ql'): 11, ('nn$-tl', 'unk'): 10, ('nn', 'np-tl'): 10, ('np-hl', 'np-hl'): 10, ('jjr', 'rbr'): 10, ('doz', 'doz'): 10, ('jj', 'jj-tl'): 10, ('nns$', 'nns$'): 10, ('nns', 'nns-tl'): 10, ('nns$-tl', 'unk'): 10, ('jjs', 'jjs'): 9, ('hvn', 'hvd'): 9, ('np', 'nn'): 9, ('vbz-hl', 'vbz'): 9, ('jj-tl', 'nr-tl'): 9, ('ppss+hv', 'ppss+hv'): 9, ('jj', 'vbn'): 9, ('do*', 'do*'): 8, ('nn', 'rb'): 8, ('vbn-hl', 'vbd'): 8, ('nr$', 'nr$'): 8, ('vb', 'cs'): 8, ('nn-hl', 'vb'): 8, ('nn', 'ap'): 8, ('pps+md', 'pps+md'): 8, ('.-hl', '.'): 8, ('rb-hl', 'rb'): 8, ('nns$-tl', 'nns$-tl'): 7, ('nn', 'jjs'): 7, ('dod*', 'dod*'): 7, (' ...

# %%
# confusion matrix for bigram
temp = [] 
for i in bigram_tag_pre:
    w =[i[0][1][1] , i[1]]
    temp.append(w)

bi_conf_matrix = []
from collections import Counter
bi_conf_matrix =  Counter(tuple(x) for x in temp)
print(bi_conf_matrix)
# Out:
# Counter({('nn', 'nn'): 3988, ('in', 'in'): 3584, ('at', 'at'): 3049, ('np', 'np'): 1528, ('.', 'in'): 1311, (',', 'in'): 1193, ('nn', 'in'): 1136, ('jj', 'nn'): 1065, ('vb', 'vb'): 979, ('np', 'at'): 962, ('nns', 'nn'): 941, ('nn', 'at'): 741, (',', 'np'): 715, ('nn-tl', 'nn-tl'): 641, ('vbn', 'vbn'): 626, ('at', 'in'): 595, ('cc', 'in'): 564, ('nns', 'in'): 543, ('np', 'nn'): 468, ('cd', 'at'): 445, ('np', 'cc'): 445, ('in', 'at'): 431, ('cs', 'in'): 412, ('nns', 'at'): 386, ('vbd', 'in'): 378, ('to', 'in'): 375, ('pp$', 'at'): 365, ('jj', 'at'): 351, ('nns', 'nns'): 345, ('rb', 'in'): 301, ('vbd', 'np'): 293, ('at', 'cc'): 281, ('vbd', 'vbd'): 280, ('nn-tl', 'nn'): 269, ('be', 'vb'): 268, ('vbg', 'at'): 261, ('pps', 'at'): 249, ("''", 'in'): 239, ('cd', 'nn'): 239, ('md', 'in'): 231, ('cc', 'cc'): 227, ('in', 'nn'): 224, ('vbn', 'in'): 215, ('in', 'cc'): 215, ('np', 'nn-tl'): 210, ('.', 'np'): 195, ('.', '.'): 193, ('nn-tl', 'at'): 180, ('in', 'np'): 179, ('nr', 'in'): 177, ('rb', 'at'): 177, ('``', 'at'): 174, ('at', 'vbn'): 173, ('cc', 'np'): 170, ('np', 'in'): 168, ('ap', 'nn'): 162, ('jj', 'in'): 161, ('nn', 'np'): 155, ('nn', 'nn-tl'): 153, ('vbd', 'cc'): 152, ('od', 'nn'): 151, (',', 'nn-tl'): 150, ('in', 'nns'): 150, ('dt', 'at'): 149, ('jj-tl', 'nn'): 148, ('at', 'nn'): 144, ('vbg', 'in'): 140, (',', '.'): 138, ('bedz', 'in'): 136, ('rp', 'in'): 131, ('.', 'nn-tl'): 130, ('cd', 'in'): 128, ('vbg', 'nn'): 124, ('nn', 'nns'): 123, ('bez', 'in'): 122, ('nn', 'cc'): 120, ('np-tl', 'nn-tl'): 120, ('vb', 'in'): 118, ('np-tl', 'nn'): 112, ('ap', 'at'): 111, ('.', 'at'): 110, (',', 'nns'): 110, ('ppo', 'at'): 109, ('md', 'vbd'): 104, ('ben', 'vbn'): 104, ('cs', 'at'): 102, ('ppss', 'at'): 101, ('vbn', 'at'): 101, ('pps', 'cc'): 100, ('nn$', 'nn'): 99, ('vbn', 'nn'): 98, ('vbd', 'nn'): 98, ('cd', 'cc'): 98, ('pp$', 'in'): 91, ('in', 'nn-tl'): 91, ('wps', 'in'): 90, ('pps', 'in'): 87, ('np-tl', 'at'): 87, ('rb', 'vbn'): 85, ('wps', 'cc'): 82, ('to', 'at'): 81, ('rb', 'cc'): 80, ('bedz', 'vbd'): 80, ('in', 'vbn'): 80, ('.', 'nns'): 80, ('cd', 'np'): 79, ('cc', 'at'): 78, ('in-tl', 'nn-tl'): 77, ('ap', 'in'): 75, ('vbg', 'vbn'): 75, ('ppo', 'in'): 74, ('jj-tl', 'at'): 74, ('in', '.'): 74, (',', 'nn'): 73, ('cs', 'nn'): 72, ('cc', 'nn'): 72, ('cs', 'cc'): 71, ('vbz', 'in'): 68, ('rb', 'vb'): 68, ('nns-tl', 'nn-tl'): 67, ('jj', 'jj'): 67, ('nns-tl', 'nn'): 66, ('vbz', 'vbd'): 66, ('np$', 'at'): 65, ('nps', 'nn'): 64, ('jj-tl', 'nn-tl'): 63, ('np-hl', 'at'): 63, ('nr', 'at'): 62, ('rp', 'at'): 62, ('``', 'cc'): 61, ('rb', 'jj'): 59, ('md', 'np'): 59, ('hv', 'vb'): 59, ('jj', 'vbn'): 59, ('ppss', 'ppss'): 58, ('nr', 'nn'): 58, ('vbg', 'cc'): 57, ('jj', 'nns'): 57, ('bed', 'in'): 56, ('wdt', 'in'): 56, ('np-hl', 'np-hl'): 56, ('dt', 'in'): 55, ('ber', 'in'): 55, ('to', 'nn'): 55, ('nns', 'cc'): 54, ('--', 'in'): 54, ('md', 'vb'): 53, (',', ','): 52, ('rb', 'nn'): 51, ('bez', 'vbd'): 51, ('wrb', 'in'): 51, ('np$', 'np'): 51, ('jj', 'cc'): 51, ('wdt', 'at'): 50, ('bedz', 'np'): 50, ('bez', 'np'): 49, ('dti', 'at'): 48, ('hvz', 'in'): 48, ('.', 'nn'): 48, ('nns', 'nn-tl'): 48, ('ql', 'nn'): 47, ('vb', 'nn'): 47, (',-hl', ')-hl'): 46, ('cc', 'nn-tl'): 46, ('nn-tl', ','): 46, ('vbd', 'nn-tl'): 44, (',', 'at'): 44, ('ql', 'in'): 44, ('nn-hl', 'at'): 43, ('wrb', 'cc'): 43, ('pp$', 'nn'): 43, ('``', 'nn'): 41, ('``', 'in'): 41, ('md', 'cc'): 40, ('at', 'pps'): 40, ('vbn-tl', 'nn'): 39, ('.', ','): 38, ('jjt', 'nn'): 38, ('nns', 'np'): 38, ('dts', 'at'): 38, ('bedz', 'cc'): 38, ('vbd', ','): 38, ('abn', 'at'): 37, ('nn-tl', 'np'): 37, ('ex', 'at'): 37, ('rb', 'vbd'): 37, ('vbn', 'cc'): 36, ('nns-tl', 'nns-tl'): 36, ('at', 'ppss'): 36, ('nn-tl', 'np-tl'): 35, ('pps', 'pps'): 35, (':', 'in'): 35, ('vbd', 'vb'): 35, ('nn-tl', 'cc'): 35, ('ppss', 'in'): 35, ('pps', 'nn'): 34, ('hvz', 'np'): 34, ('hvz', 'vbd'): 34, ('hvd', 'in'): 34, ('wdt', 'cc'): 33, ('cs', 'np'): 33, ('wrb', 'at'): 33, ('at', 'in-hl'): 32, ('hv', 'in'): 31, ('in', ','): 31, ('r ...

# %%
# tagging unknown words in unigram model
#considering only tagging unknown words
unk_uni = []
for i in seq_unigram_tag:
    if(i[1] == 'unk'):
        temp = [i , 'nn']
        unk_uni.append(temp)
        
# accuracy of unknown words 
temp = 0
for i in unk_uni:
    if (i[0][0][1] == i[1]):
        temp+=1
        
d = len(unk_uni)
unk_accuracy = (temp/d)*100

print(unk_accuracy)
# Out:
# 11.845624761176921

# %%
# extra credit bigram model 
q = []
for i in brown_train:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_train_exp = [[]for i in range(x)]
for i in range(x-2):
    if i+1 < x:   
        bigram_train_exp[i].append( q[i] )   
        bigram_train_exp[i].append( q[i+1])
        bigram_train_exp[i].append( q[i+2])
    
#print (bigram_train_exp)

# %%
x = len(bigram_train_exp)
bigram_tag_exp = []
for i in range(x-2):
    p =[bigram_train_exp[i][0][1] , bigram_train_exp[i][1][1] , bigram_train_exp[i][2][1] ]
    bigram_tag_exp.append(p)

# %%
# getting frequency of tags from brown_train
from collections import Counter
types =  Counter(tuple(x) for x in bigram_tag_exp)
#print(types)  # types is in the form of directories

# converting dictionary into two dimentional array "a"
s = []
for value in types.items() :
    s.append(value)
#print(s)

#sorting array "a" in decending order
def sortthird(s): 
    return s[1] 
s.sort(key = sortthird ,reverse = True) 
#print(s)            # bigram_training corpus get reduced from 1111244 to 455628 pairs

q = [] 
for i in s:
    q.append(i[0])

temp =[]
bi_max_fre_word_tag_exp = []
for l in q:
    if (l[0] not in temp):
        temp.append(l[0])
        bi_max_fre_word_tag_exp.append(l)
    
#print(bi_max_fre_word_tag)  # now the size of training set come down to 519 from 1111244 word_tags pairs

# %%
#brown test model 
q = []
for i in brown_test:
    j = i.rsplit('/')
    q.append(j)
    
# forming bigram model as list from training corpus
x = len(q)
bigram_test_exp = [[]for i in range(x)]
for i in range(x-2):
    if i+1 < x:   
        bigram_test_exp[i].append( q[i] )   
        bigram_test_exp[i].append( q[i+1])
        bigram_test_exp[i].append( q[i+2])
        
#bigram_test_exp

# %%
#bigram tagger  predictions for test set from training corpus

bigram_tag_pre_exp = []
x = len(bigram_test_exp)
y = len(bi_max_fre_word_tag_exp)
for i in range(x-2):
    g = bigram_test_exp[i][0][1]
    h = bigram_test_exp[i][2][1]
    for l in range(y): 
        if (g == bi_max_fre_word_tag_exp[l][0] and h == bi_max_fre_word_tag_exp[l][0]):
            temp = [bigram_test_exp[i] , bi_max_fre_word_tag_exp[l][1]]
            bigram_tag_pre_exp.append(temp)
            break;

#bigram_tag_pre_exp  

f= open("bigram_tag_predicted_exp.txt","w+")
for i in bigram_tag_pre_exp:
     f.write(str(i))
     f.write("\n")
f.close()

# %%
#bigram pos accuray for different method
temp = 0
for i in bigram_tag_pre_exp:
    if (i[0][1][1]==i[1]):
        temp += 1
d = len(bigram_tag_pre_exp)
pos_accuracy_exp = (temp/d)*100

print(pos_accuracy_exp)
# Out:
# 33.819345661450924
